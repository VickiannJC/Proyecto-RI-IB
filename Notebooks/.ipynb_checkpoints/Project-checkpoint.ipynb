# %% [markdown]
# # Proyecto Bimestral: Sistema de Recuperación de Información basado en Reuters-21578
#
# ## 1. Introducción
# El objetivo de este proyecto es diseñar, construir, programar y desplegar un Sistema de Recuperación de Información (SRI) utilizando el corpus Reuters-21578. El proyecto se dividirá en varias fases,
# que se describen a continuación.

# %%
import os
import zipfile
import pandas as pd
import string
import nltk
import numpy as np
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from gensim.models import Word2Vec
from collections import defaultdict
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import time

# %%
# Descargar recursos de NLTK
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## 2. Fases del Proyecto
# ### 2.1. Adquisición de Datos
# - Objetivo: Obtener y preparar el corpus Reuters-21578.
# - Tareas:
#     - Descargar el corpus Reuters-21578.
#     - Descomprimir y organizar los archivos.
#     - Documentar el proceso de adquisición de datos

# %%
# Descargar y descomprimir el corpus Reuters-21578

def extract_reuters_data(zip_path, extract_to):
    """
    Extrae los datos del corpus Reuters-21578 desde un archivo zip a un directorio especificado.
    
    Parámetros:
        zip_path (str): Ruta al archivo zip que contiene los datos del corpus Reuters-21578.
        extract_to (str): Directorio de destino donde se descomprimirá el contenido del archivo zip.
    """
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        zip_ref.extractall(extract_to)
    print("Datos descomprimidos en:", extract_to)

# Configuración de las rutas al archivo zip y al directorio de destino
zip_path = r"..\reute\reuters.zip"
extract_to = r"..\reute"

# Llamada a la función para extraer los datos
extract_reuters_data(zip_path, extract_to)
# Out:
# Datos descomprimidos en: ..\reute

# %%
def change_extension_to_txt(folder_path):
    """
    Cambia la extensión de todos los archivos a .txt.
    
    Parámetros:
        folder_path (str): Ruta del directorio donde se encuentran los archivos.
    """
    if not os.path.exists(folder_path):
        print(f"La carpeta '{folder_path}' no existe. Verifica la ruta.")
        return

    for filename in os.listdir(folder_path):
        old_path = os.path.join(folder_path, filename)
        # Verificar si es un archivo regular y no una carpeta
        if os.path.isfile(old_path):
            # Cambiar la extensión a .txt
            new_filename = f"{filename}.txt" if '.' not in filename else f"{os.path.splitext(filename)[0]}.txt"
            new_path = os.path.join(folder_path, new_filename)
            os.rename(old_path, new_path)
            print(f"Archivo renombrado: {old_path} -> {new_path}")
        else:
            print(f"Omitido (no es un archivo): {old_path}")

# Ruta de la carpeta principal descomprimida
reuters_dir = r"..\reute\reuters" 

# Cambiar extensiones en las carpetas training y test
training_dir = os.path.join(reuters_dir, "training")
test_dir = os.path.join(reuters_dir, "test")

print("Procesando carpeta 'training'...")
change_extension_to_txt(training_dir)

print("Procesando carpeta 'test'...")
change_extension_to_txt(test_dir)
# Out:
# Procesando carpeta 'training'...
# Archivo renombrado: ..\reute\reuters\training\1 -> ..\reute\reuters\training\1.txt
# Archivo renombrado: ..\reute\reuters\training\10 -> ..\reute\reuters\training\10.txt
# Archivo renombrado: ..\reute\reuters\training\100 -> ..\reute\reuters\training\100.txt
# Archivo renombrado: ..\reute\reuters\training\1000 -> ..\reute\reuters\training\1000.txt
# Archivo renombrado: ..\reute\reuters\training\10000 -> ..\reute\reuters\training\10000.txt
# Archivo renombrado: ..\reute\reuters\training\10002 -> ..\reute\reuters\training\10002.txt
# Archivo renombrado: ..\reute\reuters\training\10005 -> ..\reute\reuters\training\10005.txt
# Archivo renombrado: ..\reute\reuters\training\10008 -> ..\reute\reuters\training\10008.txt
# Archivo renombrado: ..\reute\reuters\training\10011 -> ..\reute\reuters\training\10011.txt
# Archivo renombrado: ..\reute\reuters\training\10014 -> ..\reute\reuters\training\10014.txt
# Archivo renombrado: ..\reute\reuters\training\10015 -> ..\reute\reuters\training\10015.txt
# Archivo renombrado: ..\reute\reuters\training\10018 -> ..\reute\reuters\training\10018.txt
# Archivo renombrado: ..\reute\reuters\training\10023 -> ..\reute\reuters\training\10023.txt
# Archivo renombrado: ..\reute\reuters\training\10025 -> ..\reute\reuters\training\10025.txt
# Archivo renombrado: ..\reute\reuters\training\10027 -> ..\reute\reuters\training\10027.txt
# Archivo renombrado: ..\reute\reuters\training\1003 -> ..\reute\reuters\training\1003.txt
# Archivo renombrado: ..\reute\reuters\training\10032 -> ..\reute\reuters\training\10032.txt
# Archivo renombrado: ..\reute\reuters\training\10035 -> ..\reute\reuters\training\10035.txt
# Archivo renombrado: ..\reute\reuters\training\10037 -> ..\reute\reuters\training\10037.txt
# Archivo renombrado: ..\reute\reuters\training\10038 -> ..\reute\reuters\training\10038.txt
# Archivo renombrado: ..\reute\reuters\training\10040 -> ..\reute\reuters\training\10040.txt
# Archivo renombrado: ..\reute\reuters\training\10041 -> ..\reute\reuters\training\10041.txt
# Archivo renombrado: ..\reute\reuters\training\10042 -> ..\reute\reuters\training\10042.txt
# Archivo renombrado: ..\reute\reuters\training\10043 -> ..\reute\reuters\training\10043.txt
# Archivo renombrado: ..\reute\reuters\training\10046 -> ..\reute\reuters\training\10046.txt
# Archivo renombrado: ..\reute\reuters\training\10048 -> ..\reute\reuters\training\10048.txt
# Archivo renombrado: ..\reute\reuters\training\10049 -> ..\reute\reuters\training\10049.txt
# Archivo renombrado: ..\reute\reuters\training\10050 -> ..\reute\reuters\training\10050.txt
# Archivo renombrado: ..\reute\reuters\training\10052 -> ..\reute\reuters\training\10052.txt
# Archivo renombrado: ..\reute\reuters\training\10053 -> ..\reute\reuters\training\10053.txt
# Archivo renombrado: ..\reute\reuters\training\10054 -> ..\reute\reuters\training\10054.txt
# Archivo renombrado: ..\reute\reuters\training\10057 -> ..\reute\reuters\training\10057.txt
# Archivo renombrado: ..\reute\reuters\training\10058 -> ..\reute\reuters\training\10058.txt
# Archivo renombrado: ..\reute\reuters\training\10061 -> ..\reute\reuters\training\10061.txt
# Archivo renombrado: ..\reute\reuters\training\10062 -> ..\reute\reuters\training\10062.txt
# Archivo renombrado: ..\reute\reuters\training\10064 -> ..\reute\reuters\training\10064.txt
# Archivo renombrado: ..\reute\reuters\training\10065 -> ..\reute\reuters\training\10065.txt
# Archivo renombrado: ..\reute\reuters\training\10066 -> ..\reute\reuters\training\10066.txt
# Archivo renombrado: ..\reute\reuters\training\10067 -> ..\reute\reuters\training\10067.txt
# Archivo renombrado: ..\reute\reuters\training\10068 -> ..\reute\reuters\training\10068.txt
# Archivo renombrado: ..\reute\reuters\training\1007 -> ..\reute\reuters\training\1007.txt
# Archivo renombrado: ..\reute\reuters\training\10071 -> ..\reute\reuters\training\10071.txt
# Archivo renombrado: ..\reute\reuters\training\10073 -> ..\reute\reuters\training\10073.txt
# Archivo renombrado: ..\reute\reuters\training\10074 -> ..\reute\reuters\training\10074.txt
# Archivo renombrado: ..\reute\reuters\training\10075 -> ..\reute\reuters\training\10075.txt
# Archivo renombrado: ..\reute\reuters\training\10076 -> ..\reute\reuters\training\10076.txt
# Archivo renombrado: ..\reute\reuters\training\10078 -> ..\reute\reuters\training\10078.txt
# Archivo renombrado: ..\reute\reuters\training\10079 -> ..\reute\reuters\training\10079.txt
# Archivo renombrado: ..\reute\reuters\training\1008 -> ..\reute\reuters\training\1008.txt
# Archivo renombrado: ..\reute\reuters\training\10080 -> ..\reute\reuters\training\10080.txt
# Archivo renombrado: ..\reute\reuters\training\10081 -> ..\reute\reuters\training\10081.txt
# Archivo renombrado: ..\reute\reuters\training\10083 -> ..\reute\reuters\training\10083.txt
# Archivo renombrado: ..\reute\reuters\training\10085 -> ..\reute\reuters\training\10085.txt
# Archivo renombrado: ..\reute\reuters\training\10086 -> ..\reute\reuters\training\10086.txt
# Archivo renombrado: ..\reute\reuters\training\10088 -> ..\reute\reuters\training\10088.txt
# Archivo renombrado: ..\reute\reuters\training\10089 -> ..\reute\reuters\training\10089.txt
# Archivo renombrado: ..\reute\reuters\training\1009 -> ..\reute\reuters\training\1009.txt
# Archivo renombrado: ..\reute\reuters\training\10090 -> ..\reute\reuters\training\10090.txt
# Archivo renombrado: ..\reute\reuters\training\10091 -> ..\reute\reuters\training\10091.txt
# Archivo renombrado: ..\reute\reuters\training\10092 -> ..\reute\reuters\training\10092.txt
# Archivo renombrado: ..\reute\reuters\training\10094 -> ..\reute\reuters\training\10094.txt
# Archivo renombrado: ..\reute\reuters\training\10095 -> ..\reute\reuters\training\10095.txt
# Archivo renombrado: ..\reute\reuters\training\10096 -> ..\reute\reuters\training\10096.txt
# Archivo renombrado: ..\reute\reuters\training\10097 -> ..\reute\reuters\training\10097.txt
# Archivo renombrado: ..\reute\reuters\training\10098 -> ..\reute\reuters\training\10098.txt
# Archivo renombrado: ..\reute\reuters\training\10099 -> ..\reute\reuters\training\10099.txt
# Archivo renombrado: ..\reute\reuters\training\101 -> ..\reute\reuters\training\101.txt
# Archivo renombrado: ..\reute\reuters\training\1010 -> ..\reute\reuters\training\1010.txt
# Archivo renombrado: ..\reute\reuters\training\10100 -> ..\reute\reuters\training\10100.txt
# Archivo renombrado: ..\reute\reuters\training\10102 -> ..\reute\reuters\training\10102.txt
# Archivo renombrado: ..\reute\reuters\training\10105 -> ..\reute\reuters\training\10105.txt
# Archivo renombrado: ..\reute\reuters\training\10106 -> ..\reute\reuters\training\10106.txt
# Archivo renombrado: ..\reute\reuters\training\10107 -> ..\reute\reuters\training\10107.txt
# Archivo renombrado: ..\reute\reuters\training\10108 -> ..\reute\reuters\training\10108.txt
# Archivo renombrado: ..\reute\reuters\training\10109 -> ..\reute\reuters\training\10109.txt
# Archivo renombrado: ..\reute\reuters\training\1011 -> ..\reute\reuters\training\1011.txt
# Archivo renombrado: ..\reute\reuters\training\10110 -> ..\reute\reuters\training\10110.txt
# Archivo renombrado: ..\reute\reuters\training\10112 -> ..\reute\reuters\training\10112.txt
# Archivo renombrado: ..\reute\reuters\training\10114 -> ..\reute\reuters\training\10114.txt
# Archivo renombrado: ..\reute\reuters\training\10115 -> ..\reute\reuters\training\10115.txt
# Archivo renombrado: ..\reute\reuters\training\10119 -> ..\reute\reuters\training\10119.txt
# Archivo renombrado: ..\reute\reuters\training\10120 -> ..\reute\reuters\training\10120.txt
# Archivo renombrado: ..\reute\reuters\training\10122 -> ..\reute\reuters\training\10122.txt
# Archivo renombrado: ..\reute\reuters\training\10124 -> ..\reute\reuters\training\10124.txt
# Archivo renombrado: ..\reute\reuters\training\10128 -> ..\reute\reuters\training\10128.txt
# Archivo renombrado: ..\reute\reuters\training\10129 -> ..\reute\reuters\training\10129.txt
# Archivo renombrado: ..\reute\reuters\training\1013 -> ..\reute\reuters\training\1013.txt
# Archivo renombrado: ..\reute\reuters\training\10130 -> ..\reute\reuters\training\10130.txt
# Archivo renombrado: ..\reute\reuters\training\10135 -> ..\reute\reuters\training\10135.txt
# Archivo renombrado: ..\reute\reuters\training\10136 -> ..\reute\reuters\training\10136.txt
# Archivo renombrado: ..\reute\reuters\training\10139 -> ..\reute\reuters\training\10139.txt
# Archivo renombrado: ..\reute\reuters\training\10140 -> ..\reute\reuters\training\10140.txt
# Archivo renombrado: ..\reute\reuters\training\10146 -> ..\reute\reuters\training\10146.txt
# Archivo renombrado: ..\reute\reuters\training\1015 -> ..\reute\reuters\training\1015.txt
# Archivo renombrado: ..\reute\reuters\training\10151 -> ..\reute\reuters\training\10151.txt
# Archivo renombrado: ..\reute\reuters\training\10153 -> ..\reute\reuters\training\10153.txt
# Archivo renombrado: ..\reute\reuters\training\10154 -> ..\reute\reuters\training\10154.txt
# Archivo renombrado: ..\reute\reuters\training\10155 -> ..\reute\reuters\training\10155.txt
# Archivo renombrado: ..\reute\reuters\training\10156 -> ..\reute\reuters\training\10156.txt
# Archivo renombrado: ..\reute\reuters\training\10158 -> ..\reute\reuters\training\10158.txt
# Archivo renombrado: ..\reute\reuters\training\1016 -> ..\reute\reuters\training\1016.txt
# Archivo renombrado: ..\reute\reuters\training\10162 -> ..\reute\reuters\training\10162.txt
# Archivo renombrado: ..\reute\reuters\training\10163 -> ..\reute\reuters\training\10163.txt
# Archivo renombrado: ..\reute\reuters\training\10165 -> ..\reute\reuters\training\10165.txt
# Archivo renombrado: ..\reute\reuters\training\10168 -> ..\reute\reuters\training\10168.txt
# Archivo renombrado: ..\reute\reuters\training\1017 -> ..\reute\reuters\training\1017.txt
# Archivo renombrado: ..\reute\reuters\training\10171 -> ..\reute\reuters\training\10171.txt
# Archivo renombrado: ..\reute\reuters\training\10172 -> ..\reute\reuters\training\10172.txt
# Archivo renombrado: ..\reute\reuters\training\10173 -> ..\reute\reuters\training\10173.txt
# Archivo renombrado: ..\reute\reuters\training\10174 -> ..\reute\reuters\training\10174.txt
# Archivo renombrado: ..\reute\reuters\training\10175 -> ..\reute\reuters\training\10175.txt
# Archivo renombrado: ..\reute\reuters\training\10176 -> ..\reute\reuters\training\10176.txt
# Archivo renombrado: ..\reute\reuters\training\10177 -> ..\reute\reuters\training\10177.txt
# Archivo renombrado: ..\reute\reuters\training\10178 -> ..\reute\reuters\training\10178.txt
# Archivo renombrado: ..\reute\reuters\training\10180 -> ..\reute\reuters\training\10180.txt
# Archivo renombrado: ..\reute\reuters\training\10181 -> ..\reute\reuters\training\10181.txt
# Archivo renombrado: ..\reute\reuters\training\10183 -> ..\reute\reuters\training\10183.txt
# Archivo renombrado: ..\reute\reuters\training\10185 -> ..\reute\reuters\training\10185.txt
# Archivo renombrado: ..\reute\reuters\training\10186 -> ..\reute\reuters\training\10186.txt
# Archivo renombrado: ..\reute\reuters\training\1019 -> ..\reute\reuters\training\1019.txt
# Archivo renombrado: ..\reute\reuters\training\10190 -> ..\reute\reuters\training\10190.txt
# Archivo renombrado: ..\reute\reuters\training\10191 -> ..\reute\reuters\training\10191.txt
# Archivo renombrado: ..\reute\reuters\training\10192 -> ..\reute\reuters\training\10192.txt
# Archivo renombrado: ..\reute\reuters\training\10196 -> ..\reute\reuters\training\10196.txt
# Archivo renombrado: ..\reute\reuters\training\10197 -> ..\reute\reuters\training\10197.txt
# Archivo renombrado: ..\reute\reuters\training\102 -> ..\reute\reuters\training\102.txt
# Archivo renombrado: ..\reute\reuters\training\1020 -> ..\reute\reuters\training\1020.txt
# Archivo renombrado: ..\reute\reuters\training\10200 -> ..\reute\reuters\training\10200.txt
# Archivo renombrado: ..\reute\reuters\training\10201 -> ..\reute\reuters\training\10201.txt
# Archivo renombrado: ..\reute\reuters\training\10207 -> ..\reute\reuters\training\10207.txt
# Archivo renombrado: ..\reute\reuters\training\10208 -> ..\reute\reuters\training\10208.txt
# Archivo renombrado: ..\reute\reuters\training\10209 -> ..\reute\reuters\training\10209.txt
# Archivo renombrado: ..\reute\reuters\training\10211 -> ..\reute\reuters\training\10211.txt
# Archivo renombrado: ..\reute\reuters\training\10213 -> ..\reute\reuters\training\10213.txt
# Archivo renombrado: ..\reute\reuters\training\10214 -> ..\reute\reuters\training\10214.txt
# Archivo renombrado: ..\reute\reuters\training\10215 -> ..\reute\reuters\training\10215.txt
# Archivo renombrado: ..\reute\reuters\training\10216 -> ..\reute\reuters\training\10216.txt
# Archivo renombrado: ..\reute\reuters\training\10218 -> ..\reute\reuters\training\10218.txt
# Archivo renombrado: ..\reute\reuters\training\10219 -> ..\reute\reuters\training\10219.txt
# Archivo renombrado: ..\reute\reuters\training\1022 -> ..\reute\reuters\training\1022.txt
# Archivo renombrado: ..\reute\reuters\training\10222 -> ..\reute\reuters\training\10222.txt
# Archivo renombrado: ..\reute\reuters\training\10224 -> ..\reute\reuters\training\10224.txt
# Archivo renombrado: ..\reute\reuters\training\10225 -> ..\reute\reuters\training\10225.txt
# Archivo renombrado: ..\reute\reuters\training\10227 -> ..\reute\reuters\training\10227.txt
# Archivo renombrado: ..\reute\reuters\training\10228 -> ..\reute\reuters\training\10228.txt
# Archivo renombrado: ..\reute\reuters\training\1023 -> ..\reute\reuters\training\1023.txt
# Archivo renombrado: ..\reute\reuters\training\10230 -> ..\reute\reuters\training\10230.txt
# Archivo renombrado: ..\reute\reuters\training\10231 -> ..\reute\reuters\training\10231.txt
# Archivo renombrado: ..\reute\reuters\training\10233 -> ..\reute\reuters\training\10233.txt
# Archivo renombrado: ..\reute\reuters\training\10235 -> ..\reute\reuters\training\10235.txt
# Archivo renombrado: ..\reute\reuters\training\10237 -> ..\reute\reuters\training\10237.txt
# Archivo renombrado: ..\reute\reuters\training\10238 -> ..\reute\reuters\training\10238.txt
# Archivo renombrado: ..\reute\reuters\training\1024 -> ..\reute\reuters\training\1024.txt
# Archivo renombrado: ..\reute\reuters\training\10240 -> ..\reute\reuters\training\10240.txt
# Archivo renombrado: ..\reute\reuters\training\10242 -> ..\reute\reuters\training\10242.txt
# Archivo renombrado: ..\reute\reuters\training\10243 -> ..\reute\reuters\training\10243.txt
# Archivo renombrado: ..\reute\reuters\training\10245 -> ..\reute\reuters\training\10245.txt
# Archivo renombrado: ..\reute\reuters\training\10246 -> ..\reute\reuters\training\10246.txt
# Archivo renombrado: ..\reute\reuters\training\10253 -> ..\reute\reuters\training\10253.txt
# Archivo renombrado: ..\reute\reuters\training\10254 -> ..\reute\reuters\training\10254.txt
# Archivo renombrado: ..\reute\reuters\training\10255 -> ..\reute\reuters\training\10255.txt
# Archivo renombrado: ..\reute\reuters\training\10258 -> ..\reute\reuters\training\10258.txt
# Archivo renombrado: ..\reute\reuters\training\1026 -> ..\reute\reuters\training\1026.txt
# Archivo renombrado: ..\reute\reuters\training\10260 -> ..\reute\reuters\training\10260.txt
# Archivo renombrado: ..\reute\reuters\training\10261 -> ..\reute\reuters\training\10261.txt
# Archivo renombrado: ..\reute\reuters\training\10262 -> ..\reute\reuters\training\10262.txt
# Archivo renombrado: ..\reute\reuters\training\10263 -> ..\reute\reuters\training\10263.txt
# Archivo renombrado: ..\reute\reuters\training\10264 -> ..\reute\reuters\training\10264.txt
# Archivo renombrado: ..\reute\reuters\training\10265 -> ..\reute\reuters\training\10265.txt
# Archivo renombrado: ..\reute\reuters\training\10268 -> ..\reute\reuters\training\10268.txt
# Archivo renombrado: ..\reute\reuters\training\10272 -> ..\reute\reuters\training\10272.txt
# Archivo renombrado: ..\reute\reuters\training\10275 -> ..\reute\reuters\training\10275.txt
# Archivo renombrado: ..\reute\reuters\training\10277 -> ..\reute\reuters\training\10277.txt
# Archivo renombrado: ..\reute\reuters\training\10280 -> ..\reute\reuters\training\10280.txt
# Archivo renombrado: ..\reute\reuters\training\10281 -> ..\reute\reuters\training\10281.txt
# Archivo renombrado: ..\reute\reuters\training\10282 -> ..\reute\reuters\training\10282.txt
# Archivo renombrado: ..\reute\reuters\training\10283 -> ..\reute\reuters\training\10283.txt
# Archivo renombrado: ..\reute\reuters\training\10284 -> ..\reute\reuters\training\10284.txt
# Archivo renombrado: ..\reute\reuters\training\10285 -> ..\reute\reuters\training\10285.txt
# Archivo renombrado: ..\reute\reuters\training\10289 -> ..\reute\reuters\training\10289.txt
# Archivo renombrado: ..\reute\reuters\training\1029 -> ..\reute\reuters\training\1029.txt
# Archivo renombrado: ..\reute\reuters\training\10291 -> ..\reute\reuters\training\10291.txt
# Archivo renombrado: ..\reute\reuters\training\10292 -> ..\reute\reuters\training\10292.txt
# Archivo renombrado: ..\reute\reuters\training\10294 -> ..\reute\reuters\training\10294.txt
# Archivo renombrado: ..\reute\reuters\training\10295 -> ..\reute\reuters\training\10295.txt
# Archivo renombrado: ..\reute\reuters\training\10297 -> ..\reute\reuters\training\10297.txt
# Archivo renombrado: ..\reute\reuters\training\10299 -> ..\reute\reuters\training\10299.txt
# Archivo renombrado: ..\reute\reuters\training\103 -> ..\reute\reuters\training\103.txt
# Archivo renombrado: ..\reute\reuters\training\1030 -> ..\reute\reuters\training\1030.txt
# Archivo renombrado: ..\reute\reuters\training\10300 -> ..\reute\reuters\training\10300.txt
# Archivo renombrado: ..\reute\reuters\training\10302 -> ..\reute\reuters\training\10302.txt
# Archivo renombrado: ..\reute\reuters\training\10305 -> ..\reute\reuters\training\10305.txt
# Archivo renombrado: ..\reute\reuters\training\10306 -> ..\reute\reuters\training\10306.txt
# Archivo renombrado: ..\reute\reuters\training\10308 -> ..\reute\reuters\training\10308.txt
# Archivo renombrado: ..\reute\reuters\training\10310 -> ..\reute\reuters\training\10310.txt
# Archivo renombrado: ..\reute\reuters\training\10311 -> ..\reute\reuters\training\10311.txt
# Archivo renombrado: ..\reute\reuters\training\10313 -> ..\reute\reuters\training\10313.txt
# Archivo renombrado: ..\reute\reuters\training\10314 -> ..\reute\reuters\training\10314.txt
# Archivo renombrado: ..\reute\reuters\training\10315 -> ..\reute\reuters\training\10315.txt
# Archivo renombrado: ..\reute\reuters\training\10318 -> ..\reute\reuters\training\10318.txt
# Archivo renombrado: ..\reute\reuters\training\10319 -> ..\reute\reuters\training\10319.txt
# Archivo renombrado: ..\reute\reuters\training\1032 -> ..\reute\reuters\training\1032.txt
# Archivo renombrado: ..\reute\reuters\training\10321 -> ..\reute\reuters\training\10321.txt
# Archivo renombrado: ..\reute\reuters\training\10322 -> ..\reute\reuters\training\10322.txt
# Archivo renombrado: ..\reute\reuters\training\10323 -> ..\reute\reuters\training\10323.txt
# Archivo renombrado: ..\reute\reuters\training\10324 -> ..\reute\reuters\training\10324.txt
# Archivo renombrado: ..\reute\reuters\training\10328 -> ..\reute\reuters\training\10328.txt
# Archivo renombrado: ..\reute\reuters\training\1033 -> ..\reute\reuters\training\1033.txt
# Archivo renombrado: ..\reute\reuters\training\10330 -> ..\reute\reuters\training\10330.txt
# Archivo renombrado: ..\reute\reuters\training\10332 -> ..\reute\reuters\training\10332.txt
# Archivo renombrado: ..\reute\reuters\training\10334 -> ..\reute\reuters\training\10334.txt
# Archivo renombrado: ..\reute\reuters\training\10335 -> ..\reute\reuters\training\10335.txt
# Archivo renombrado: ..\reute\reuters\training\10337 -> ..\reute\reuters\training\10337.txt
# Archivo renombrado: ..\reute\reuters\training\10338 -> ..\reute\reuters\training\10338.txt
# Archivo renombrado: ..\reute\reuters\training\10339 -> ..\reute\reuters\training\10339.txt
# Archivo renombrado: ..\reute\reuters\training\10340 -> ..\reute\reuters\training\10340.txt
# Archivo renombrado: ..\reute\reuters\training\10341 -> ..\reute\reuters\training\10341.txt
# Archivo renombrado: ..\reute\reuters\training\10342 -> ..\reute\reuters\training\10342.txt
# Archivo renombrado: ..\reute\reuters\training\10344 -> ..\reute\reuters\training\10344.txt
# Archivo renombrado: ..\reute\reuters\training\10347 -> ..\reute\reuters\training\10347.txt
# Archivo renombrado: ..\reute\reuters\training\10348 -> ..\reute\reuters\training\10348.txt
# Archivo renombrado: ..\reute\reuters\training\10349 -> ..\reute\reuters\training\10349.txt
# Archivo renombrado: ..\reute\reuters\training\1035 -> ..\reute\reuters\training\1035.txt
# Archivo renombrado: ..\reute\reuters\training\10352 -> ..\reute\reuters\training\10352.txt
# Archivo renombrado: ..\reute\reuters\training\10354 -> ..\reute\reuters\training\10354.txt
# Archivo renombrado: ..\reute\reuters\training\10355 -> ..\reute\reuters\training\10355.txt
# Archivo renombrado: ..\reute\reuters\training\10356 -> ..\reute\reuters\training\10356.txt
# Archivo renombrado: ..\reute\reuters\training\10357 -> ..\reute\reuters\training\10357.txt
# Archivo renombrado: ..\reute\reuters\training\10358 -> ..\reute\reuters\training\10358.txt
# Archivo renombrado: ..\reute\reuters\training\10359 -> ..\reute\reuters\training\10359.txt
# Archivo renombrado: ..\reute\reuters\training\1036 -> ..\reute\reuters\training\1036.txt
# Archivo renombrado: ..\reute\reuters\training\10361 -> ..\reute\reuters\training\10361.txt
# Archivo renombrado: ..\reute\reuters\training\10362 -> ..\reute\reuters\training\10362.txt
# Archivo renombrado: ..\reute\reuters\training\10364 -> ..\reute\reuters\training\10364.txt
# Archivo renombrado: ..\reute\reuters\training\10367 -> ..\reute\reuters\training\10367.txt
# Archivo renombrado: ..\reute\reuters\training\10368 -> ..\reute\reuters\training\10368.txt
# Archivo renombrado: ..\reute\reuters\training\10370 -> ..\reute\reuters\training\10370.txt
# Archivo renombrado: ..\reute\reuters\training\10371 -> ..\reute\reuters\training\10371.txt
# Archivo renombrado: ..\reute\reuters\training\10372 -> ..\reute\reuters\training\10372.txt
# Archivo renombrado: ..\reute\reuters\training\10373 -> ..\reute\reuters\training\10373.txt
# Archivo renombrado: ..\reute\reuters\training\10375 -> ..\reute\reuters\training\10375.txt
# Archivo renombrado: ..\reute\reuters\training\10376 -> ..\reute\reuters\training\10376.txt
# Archivo renombrado: ..\reute\reuters\training\10377 -> ..\reute\reuters\training\10377.txt
# Archivo renombrado: ..\reute\reuters\training\10381 -> ..\reute\reuters\training\10381.txt
# Archivo renombrado: ..\reute\reuters\training\10382 -> ..\reute\reuters\training\10382.txt
# Archivo renombrado: ..\reute\reuters\training\10384 -> ..\reute\reuters\training\10384.txt
# Archivo renombrado: ..\reute\reuters\training\10385 -> ..\reute\reuters\training\10385.txt
# Archivo renombrado: ..\reute\reuters\training\10387 -> ..\reute\reuters\training\10387.txt
# Archivo renombrado: ..\reute\reuters\training\10388 -> ..\reute\reuters\training\10388.txt
# Archivo renombrado: ..\reute\reuters\training\1039 -> ..\reute\reuters\training\1039.txt
# Archivo renombrado: ..\reute\reuters\training\10390 -> ..\reute\reuters\training\10390.txt
# Archivo renombrado: ..\reute\reuters\training\10391 -> ..\reute\reuters\training\10391.txt
# Archivo renombrado: ..\reute\reuters\training\10393 -> ..\reute\reuters\training\10393.txt
# Archivo renombrado: ..\reute\reuters\training\10394 -> ..\reute\reuters\training\10394.txt
# Archivo renombrado: ..\reute\reuters\training\10395 -> ..\reute\reuters\training\10395.txt
# Archivo renombrado: ..\reute\reuters\training\10397 -> ..\reute\reuters\training\10397.txt
# Archivo renombrado: ..\reute\reuters\training\10398 -> ..\reute\reuters\training\10398.txt
# Archivo renombrado: ..\reute\reuters\training\10399 -> ..\reute\reuters\training\10399.txt
# Archivo renombrado: ..\reute\reuters\training\104 -> ..\reute\reuters\training\104.txt
# Archivo renombrado: ..\reute\reuters\training\1040 -> ..\reute\reuters\training\1040.txt
# Archivo renombrado: ..\reute\reuters\training\10401 -> ..\reute\reuters\training\10401.txt
# Archivo renombrado: ..\reute\reuters\training\10402 -> ..\reute\reuters\training\10402.txt
# Archivo renombrado: ..\reute\reuters\training\10403 -> ..\reute\reuters\training\10403.txt
# Archivo renombrado: ..\reute\reuters\training\10404 -> ..\reute\reuters\training\10404.txt
# Archivo renombrado: ..\reute\reuters\training\10406 -> ..\reute\reuters\training\10406.txt
# Archivo renombrado: ..\reute\reuters\training\10411 -> ..\reute\reuters\training\10411.txt
# Archivo renombrado: ..\reute\reuters\training\10412 -> ..\reute\reuters\training\10412.txt
# Archivo renombrado: ..\reute\reuters\training\10414 -> ..\reute\reuters\training\10414.txt
# Archivo renombrado: ..\reute\reuters\training\10416 -> ..\reute\reuters\training\10416.txt
# Archivo renombrado: ..\reute\reuters\training\10418 -> ..\reute\reuters\training\10418.txt
# Archivo renombrado: ..\reute\reuters\training\10419 -> ..\reute\reuters\training\10419.txt
# Archivo renombrado: ..\reute\reuters\training\10423 -> ..\reute\reuters\training\10423.txt
# Archivo renombrado: ..\reute\reuters\training\10427 -> ..\reute\reuters\training\10427.txt
# Archivo renombrado: ..\reute\reuters\training\10429 -> ..\reute\reuters\training\10429.txt
# Archivo renombrado: ..\reute\reuters\training\10430 -> ..\reute\reuters\training\10430.txt
# Archivo renombrado: ..\reute\reuters\training\10431 -> ..\reute\reuters\training\10431.txt
# Archivo renombrado: ..\reute\reuters\training\10432 -> ..\reute\reuters\training\10432.txt
# Archivo renombrado: ..\reute\reuters\training\10434 -> ..\reute\reuters\training\10434.txt
# Archivo renombrado: ..\reute\reuters\training\10435 -> ..\reute\reuters\training\10435.txt
# Archivo renombrado: ..\reute\reuters\training\10436 -> ..\reute\reuters\training\10436.txt
# Archivo renombrado: ..\reute\reuters\training\10439 -> ..\reute\reuters\training\10439.txt
# Archivo renombrado: ..\reute\reuters\training\1044 -> ..\reute\reuters\training\1044.txt
# Archivo renombrado: ..\reute\reuters\training\10440 -> ..\reute\reuters\training\10440.txt
# Archivo renombrado: ..\reute\reuters\training\10442 -> ..\reute\reuters\training\10442.txt
# Archivo renombrado: ..\reute\reuters\training\10444 -> ..\reute\reuters\training\10444.txt
# Archivo renombrado: ..\reute\reuters\training\10445 -> ..\reute\reuters\training\10445.txt
# Archivo renombrado: ..\reute\reuters\training\10446 -> ..\reute\reuters\training\10446.txt
# Archivo renombrado: ..\reute\reuters\training\10447 -> ..\reute\reuters\training\10447.txt
# Archivo renombrado: ..\reute\reuters\training\10449 -> ..\reute\reuters\training\10449.txt
# Archivo renombrado: ..\reute\reuters\training\10452 -> ..\reute\reuters\training\10452.txt
# Archivo renombrado: ..\reute\reuters\training\10453 -> ..\reute\reuters\training\10453.txt
# Archivo renombrado: ..\reute\reuters\training\10454 -> ..\reute\reuters\training\10454.txt
# Archivo renombrado: ..\reute\reuters\training\10455 -> ..\reute\reuters\training\10455.txt
# Archivo renombrado: ..\reute\reuters\training\10458 -> ..\reute\reuters\training\10458.txt
# Archivo renombrado: ..\reute\reuters\training\10459 -> ..\reute\reuters\training\10459.txt
# Archivo renombrado: ..\reute\reuters\training\10462 -> ..\reute\reuters\training\10462.txt
# Archivo renombrado: ..\reute\reuters\training\10464 -> ..\reute\reuters\training\10464.txt
# Archivo renombrado: ..\reute\reuters\training\10467 -> ..\reute\reuters\training\10467.txt
# Archivo renombrado: ..\reute\reuters\training\1047 -> ..\reute\reuters\training\1047.txt
# Archivo renombrado: ..\reute\reuters\training\10470 -> ..\reute\reuters\training\10470.txt
# Archivo renombrado: ..\reute\reuters\training\10471 -> ..\reute\reuters\training\10471.txt
# Archivo renombrado: ..\reute\reuters\training\10472 -> ..\reute\reuters\training\10472.txt
# Archivo renombrado: ..\reute\reuters\training\10473 -> ..\reute\reuters\training\10473.txt
# Archivo renombrado: ..\reute\reuters\training\10475 -> ..\reute\reuters\training\10475.txt
# Archivo renombrado: ..\reute\reuters\training\10478 -> ..\reute\reuters\training\10478.txt
# Archivo renombrado: ..\reute\reuters\training\10484 -> ..\reute\reuters\training\10484.txt
# Archivo renombrado: ..\reute\reuters\training\10485 -> ..\reute\reuters\training\10485.txt
# Archivo renombrado: ..\reute\reuters\training\10487 -> ..\reute\reuters\training\10487.txt
# Archivo renombrado: ..\reute\reuters\training\10489 -> ..\reute\reuters\training\10489.txt
# Archivo renombrado: ..\reute\reuters\training\1049 -> ..\reute\reuters\training\1049.txt
# Archivo renombrado: ..\reute\reuters\training\10491 -> ..\reute\reuters\training\10491.txt
# Archivo renombrado: ..\reute\reuters\training\10494 -> ..\reute\reuters\training\10494.txt
# Archivo renombrado: ..\reute\reuters\training\10498 -> ..\reute\reuters\training\10498.txt
# Archivo renombrado: ..\reute\reuters\training\10499 -> ..\reute\reuters\training\10499.txt
# Archivo renombrado: ..\reute\reuters\training\105 -> ..\reute\reuters\training\105.txt
# Archivo renombrado: ..\reute\reuters\training\1050 -> ..\reute\reuters\training\1050.txt
# Archivo renombrado: ..\reute\reuters\training\10500 -> ..\reute\reuters\training\10500.txt
# Archivo renombrado: ..\reute\reuters\training\10503 -> ..\reute\reuters\training\10503.txt
# Archivo renombrado: ..\reute\reuters\training\10505 -> ..\reute\reuters\training\10505.txt
# Archivo renombrado: ..\reute\reuters\training\10506 -> ..\reute\reuters\training\10506.txt
# Archivo renombrado: ..\reute\reuters\training\10508 -> ..\reute\reuters\training\10508.txt
# Archivo renombrado: ..\reute\reuters\training\10509 -> ..\reute\reuters\training\10509.txt
# Archivo renombrado: ..\reute\reuters\training\10515 -> ..\reute\reuters\training\10515.txt
# Archivo renombrado: ..\reute\reuters\training\10518 -> ..\reute\reuters\training\10518.txt
# Archivo renombrado: ..\reute\reuters\training\10519 -> ..\reute\reuters\training\10519.txt
# Archivo renombrado: ..\reute\reuters\training\1052 -> ..\reute\reuters\training\1052.txt
# Archivo renombrado: ..\reute\reuters\training\10520 -> ..\reute\reuters\training\10520.txt
# Archivo renombrado: ..\reute\reuters\training\10521 -> ..\reute\reuters\training\10521.txt
# Archivo renombrado: ..\reute\reuters\training\10524 -> ..\reute\reuters\training\10524.txt
# Archivo renombrado: ..\reute\reuters\training\10527 -> ..\reute\reuters\training\10527.txt
# Archivo renombrado: ..\reute\reuters\training\10529 -> ..\reute\reuters\training\10529.txt
# Archivo renombrado: ..\reute\reuters\training\10530 -> ..\reute\reuters\training\10530.txt
# Archivo renombrado: ..\reute\reuters\training\10531 -> ..\reute\reuters\training\10531.txt
# Archivo renombrado: ..\reute\reuters\training\10532 -> ..\reute\reuters\training\10532.txt
# Archivo renombrado: ..\reute\reuters\training\10534 -> ..\reute\reuters\training\10534.txt
# Archivo renombrado: ..\reute\reuters\training\10536 -> ..\reute\reuters\training\10536.txt
# Archivo renombrado: ..\reute\reuters\training\10537 -> ..\reute\reuters\training\10537.txt
# Archivo renombrado: ..\reute\reuters\training\10538 -> ..\reute\reuters\training\10538.txt
# Archivo renombrado: ..\reute\reuters\training\10539 -> ..\reute\reuters\training\10539.txt
# Archivo renombrado: ..\reute\reuters\training\10541 -> ..\reute\reuters\training\10541.txt
# Archivo renombrado: ..\reute\reuters\training\10542 -> ..\reute\reuters\training\10542.txt
# Archivo renombrado: ..\reute\reuters\training\10544 -> ..\reute\reuters\training\10544.txt
# Archivo renombrado: ..\reute\reuters\training\10545 -> ..\reute\reuters\training\10545.txt
# Archivo renombrado: ..\reute\reuters\training\10546 -> ..\reute\reuters\training\10546.txt
# Archivo renombrado: ..\reute\reuters\training\10547 -> ..\reute\reuters\training\10547.txt
# Archivo renombrado: ..\reute\reuters\training\10548 -> ..\reute\reuters\training\10548.txt
# Archivo renombrado: ..\reute\reuters\training\10551 -> ..\reute\reuters\training\10551.txt
# Archivo renombrado: ..\reute\reuters\training\10553 -> ..\reute\reuters\training\10553.txt
# Archivo renombrado: ..\reute\reuters\training\10555 -> ..\reute\reuters\training\10555.txt
# Archivo renombrado: ..\reute\reuters\training\10556 -> ..\reute\reuters\training\10556.txt
# Archivo renombrado: ..\reute\reuters\training\10559 -> ..\reute\reuters\training\10559.txt
# Archivo renombrado: ..\reute\reuters\training\10561 -> ..\reute\reuters\training\10561.txt
# Archivo renombrado: ..\reute\reuters\training\10563 -> ..\reute\reuters\training\10563.txt
# Archivo renombrado: ..\reute\reuters\training\10564 -> ..\reute\reuters\training\10564.txt
# Archivo renombrado: ..\reute\reuters\training\10565 -> ..\reute\reuters\training\10565.txt
# Archivo renombrado: ..\reute\reuters\training\10566 -> ..\reute\reuters\training\10566.txt
# Archivo renombrado: ..\reute\reuters\training\10567 -> ..\reute\reuters\training\10567.txt
# Archivo renombrado: ..\reute\reuters\training\10569 -> ..\reute\reuters\training\10569.txt
# Archivo renombrado: ..\reute\reuters\training\1057 -> ..\reute\reuters\training\1057.txt
# Archivo renombrado: ..\reute\reuters\training\10573 -> ..\reute\reuters\training\10573.txt
# Archivo renombrado: ..\reute\reuters\training\10576 -> ..\reute\reuters\training\10576.txt
# Archivo renombrado: ..\reute\reuters\training\1058 -> ..\reute\reuters\training\1058.txt
# Archivo renombrado: ..\reute\reuters\training\10581 -> ..\reute\reuters\training\10581.txt
# Archivo renombrado: ..\reute\reuters\training\10582 -> ..\reute\reuters\training\10582.txt
# Archivo renombrado: ..\reute\reuters\training\10584 -> ..\reute\reuters\training\10584.txt
# Archivo renombrado: ..\reute\reuters\training\10585 -> ..\reute\reuters\training\10585.txt
# Archivo renombrado: ..\reute\reuters\training\10586 -> ..\reute\reuters\training\10586.txt
# Archivo renombrado: ..\reute\reuters\training\10587 -> ..\reute\reuters\training\10587.txt
# Archivo renombrado: ..\reute\reuters\training\10588 -> ..\reute\reuters\training\10588.txt
# Archivo renombrado: ..\reute\reuters\training\1059 -> ..\reute\reuters\training\1059.txt
# Archivo renombrado: ..\reute\reuters\training\10590 -> ..\reute\reuters\training\10590.txt
# Archivo renombrado: ..\reute\reuters\training\10592 -> ..\reute\reuters\training\10592.txt
# Archivo renombrado: ..\reute\reuters\training\10593 -> ..\reute\reuters\training\10593.txt
# Archivo renombrado: ..\reute\reuters\training\10594 -> ..\reute\reuters\training\10594.txt
# Archivo renombrado: ..\reute\reuters\training\10596 -> ..\reute\reuters\training\10596.txt
# Archivo renombrado: ..\reute\reuters\training\10597 -> ..\reute\reuters\training\10597.txt
# Archivo renombrado: ..\reute\reuters\training\10598 -> ..\reute\reuters\training\10598.txt
# Archivo renombrado: ..\reute\reuters\training\10599 -> ..\reute\reuters\training\10599.txt
# Archivo renombrado: ..\reute\reuters\training\106 -> ..\reute\reuters\training\106.txt
# Archivo renombrado: ..\reute\reuters\training\10600 -> ..\reute\reuters\training\10600.txt
# Archivo renombrado: ..\reute\reuters\training\10601 -> ..\reute\reuters\training\10601.txt
# Archivo renombrado: ..\reute\reuters\training\10602 -> ..\reute\reuters\training\10602.txt
# Archivo renombrado: ..\reute\reuters\training\10604 -> ..\reute\reuters\training\10604.txt
# Archivo renombrado: ..\reute\reuters\training\10606 -> ..\reute\reuters\training\10606.txt
# Archivo renombrado: ..\reute\reuters\training\10608 -> ..\reute\reuters\training\10608.txt
# Archivo renombrado: ..\reute\reuters\training\10609 -> ..\reute\reuters\training\10609.txt
# Archivo renombrado: ..\reute\reuters\training\10610 -> ..\reute\reuters\training\10610.txt
# Archivo renombrado: ..\reute\reuters\training\10611 -> ..\reute\reuters\training\10611.txt
# Archivo renombrado: ..\reute\reuters\training\10612 -> ..\reute\reuters\training\10612.txt
# Archivo renombrado: ..\reute\reuters\training\10613 -> ..\reute\reuters\training\10613.txt
# Archivo renombrado: ..\reute\reuters\training\10615 -> ..\reute\reuters\training\10615.txt
# Archivo renombrado: ..\reute\reuters\training\10616 -> ..\reute\reuters\training\10616.txt
# Archivo renombrado: ..\reute\reuters\training\10617 -> ..\reute\reuters\training\10617.txt
# Archivo renombrado: ..\reute\reuters\training\10618 -> ..\reute\reuters\training\10618.txt
# Archivo renombrado: ..\reute\reuters\training\10619 -> ..\reute\reuters\training\10619.txt
# Archivo renombrado: ..\reute\reuters\training\10620 -> ..\reute\reuters\training\10620.txt
# Archivo renombrado: ..\reute\reuters\training\10621 -> ..\reute\reuters\training\10621.txt
# Archivo renombrado: ..\reute\reuters\training\10622 -> ..\reute\reuters\training\10622.txt
# Archivo renombrado: ..\reute\reuters\training\10623 -> ..\reute\reuters\training\10623.txt
# Archivo renombrado: ..\reute\reuters\training\10625 -> ..\reute\reuters\training\10625.txt
# Archivo renombrado: ..\reute\reuters\training\10627 -> ..\reute\reuters\training\10627.txt
# Archivo renombrado: ..\reute\reuters\training\1063 -> ..\reute\reuters\training\1063.txt
# Archivo renombrado: ..\reute\reuters\training\10632 -> ..\reute\reuters\training\10632.txt
# Archivo renombrado: ..\reute\reuters\training\10633 -> ..\reute\reuters\training\10633.txt
# Archivo renombrado: ..\reute\reuters\training\10634 -> ..\reute\reuters\training\10634.txt
# Archivo renombrado: ..\reute\reuters\training\10636 -> ..\reute\reuters\training\10636.txt
# Archivo renombrado: ..\reute\reuters\training\10638 -> ..\reute\reuters\training\10638.txt
# Archivo renombrado: ..\reute\reuters\training\10640 -> ..\reute\reuters\training\10640.txt
# Archivo renombrado: ..\reute\reuters\training\10641 -> ..\reute\reuters\training\10641.txt
# Archivo renombrado: ..\reute\reuters\training\10642 -> ..\reute\reuters\training\10642.txt
# Archivo renombrado: ..\reute\reuters\training\10643 -> ..\reute\reuters\training\10643.txt
# Archivo renombrado: ..\reute\reuters\training\10644 -> ..\reute\reuters\training\10644.txt
# Archivo renombrado: ..\reute\reuters\training\10648 -> ..\reute\reuters\training\10648.txt
# Archivo renombrado: ..\reute\reuters\training\1065 -> ..\reute\reuters\training\1065.txt
# Archivo renombrado: ..\reute\reuters\training\10650 -> ..\reute\reuters\training\10650.txt
# Archivo renombrado: ..\reute\reuters\training\10651 -> ..\reute\reuters\training\10651.txt
# Archivo renombrado: ..\reute\reuters\training\10652 -> ..\reute\reuters\training\10652.txt
# Archivo renombrado: ..\reute\reuters\training\10653 -> ..\reute\reuters\training\10653.txt
# Archivo renombrado: ..\reute\reuters\training\10654 -> ..\reute\reuters\training\10654.txt
# Archivo renombrado: ..\reute\reuters\training\10657 -> ..\reute\reuters\training\10657.txt
# Archivo renombrado: ..\reute\reuters\training\10658 -> ..\reute\reuters\training\10658.txt
# Archivo renombrado: ..\reute\reuters\training\10659 -> ..\reute\reuters\training\10659.txt
# Archivo renombrado: ..\reute\reuters\training\1066 -> ..\reute\reuters\training\1066.txt
# Archivo renombrado: ..\reute\reuters\training\10660 -> ..\reute\reuters\training\10660.txt
# Archivo renombrado: ..\reute\reuters\training\10661 -> ..\reute\reuters\training\10661.txt
# Archivo renombrado: ..\reute\reuters\training\10662 -> ..\reute\reuters\training\10662.txt
# Archivo renombrado: ..\reute\reuters\training\10665 -> ..\reute\reuters\training\10665.txt
# Archivo renombrado: ..\reute\reuters\training\10669 -> ..\reute\reuters\training\10669.txt
# Archivo renombrado: ..\reute\reuters\training\1067 -> ..\reute\reuters\training\1067.txt
# Archivo renombrado: ..\reute\reuters\training\10674 -> ..\reute\reuters\training\10674.txt
# Archivo renombrado: ..\reute\reuters\training\10676 -> ..\reute\reuters\training\10676.txt
# Archivo renombrado: ..\reute\reuters\training\10678 -> ..\reute\reuters\training\10678.txt
# Archivo renombrado: ..\reute\reuters\training\10679 -> ..\reute\reuters\training\10679.txt
# Archivo renombrado: ..\reute\reuters\training\1068 -> ..\reute\reuters\training\1068.txt
# Archivo renombrado: ..\reute\reuters\training\10681 -> ..\reute\reuters\training\10681.txt
# Archivo renombrado: ..\reute\reuters\training\10682 -> ..\reute\reuters\training\10682.txt
# Archivo renombrado: ..\reute\reuters\training\10684 -> ..\reute\reuters\training\10684.txt
# Archivo renombrado: ..\reute\reuters\training\10685 -> ..\reute\reuters\training\10685.txt
# Archivo renombrado: ..\reute\reuters\training\10687 -> ..\reute\reuters\training\10687.txt
# Archivo renombrado: ..\reute\reuters\training\10688 -> ..\reute\reuters\training\10688.txt
# Archivo renombrado: ..\reute\reuters\training\10689 -> ..\reute\reuters\training\10689.txt
# Archivo renombrado: ..\reute\reuters\training\1069 -> ..\reute\reuters\training\1069.txt
# Archivo renombrado: ..\reute\reuters\training\10692 -> ..\reute\reuters\training\10692.txt
# Archivo renombrado: ..\reute\reuters\training\10693 -> ..\reute\reuters\training\10693.txt
# Archivo renombrado: ..\reute\reuters\training\10694 -> ..\reute\reuters\training\10694.txt
# Archivo renombrado: ..\reute\reuters\training\10695 -> ..\reute\reuters\training\10695.txt
# Archivo renombrado: ..\reute\reuters\training\10696 -> ..\reute\reuters\training\10696.txt
# Archivo renombrado: ..\reute\reuters\training\10699 -> ..\reute\reuters\training\10699.txt
# Archivo renombrado: ..\reute\reuters\training\1070 -> ..\reute\reuters\training\1070.txt
# Archivo renombrado: ..\reute\reuters\training\10701 -> ..\reute\reuters\training\10701.txt
# Archivo renombrado: ..\reute\reuters\training\10702 -> ..\reute\reuters\training\10702.txt
# Archivo renombrado: ..\reute\reuters\training\10703 -> ..\reute\reuters\training\10703.txt
# Archivo renombrado: ..\reute\reuters\training\10704 -> ..\reute\reuters\training\10704.txt
# Archivo renombrado: ..\reute\reuters\training\10705 -> ..\reute\reuters\training\10705.txt
# Archivo renombrado: ..\reute\reuters\training\10708 -> ..\reute\reuters\training\10708.txt
# Archivo renombrado: ..\reute\reuters\training\10709 -> ..\reute\reuters\training\10709.txt
# Archivo renombrado: ..\reute\reuters\training\1071 -> ..\reute\reuters\training\1071.txt
# Archivo renombrado: ..\reute\reuters\training\10710 -> ..\reute\reuters\training\10710.txt
# Archivo renombrado: ..\reute\reuters\training\10712 -> ..\reute\reuters\training\10712.txt
# Archivo renombrado: ..\reute\reuters\training\10714 -> ..\reute\reuters\training\10714.txt
# Archivo renombrado: ..\reute\reuters\training\10715 -> ..\reute\reuters\training\10715.txt
# Archivo renombrado: ..\reute\reuters\training\10717 -> ..\reute\reuters\training\10717.txt
# Archivo renombrado: ..\reute\reuters\training\10718 -> ..\reute\reuters\training\10718.txt
# Archivo renombrado: ..\reute\reuters\training\1072 -> ..\reute\reuters\training\1072.txt
# Archivo renombrado: ..\reute\reuters\training\10720 -> ..\reute\reuters\training\10720.txt
# Archivo renombrado: ..\reute\reuters\training\10721 -> ..\reute\reuters\training\10721.txt
# Archivo renombrado: ..\reute\reuters\training\10724 -> ..\reute\reuters\training\10724.txt
# Archivo renombrado: ..\reute\reuters\training\10729 -> ..\reute\reuters\training\10729.txt
# Archivo renombrado: ..\reute\reuters\training\10731 -> ..\reute\reuters\training\10731.txt
# Archivo renombrado: ..\reute\reuters\training\10734 -> ..\reute\reuters\training\10734.txt
# Archivo renombrado: ..\reute\reuters\training\10736 -> ..\reute\reuters\training\10736.txt
# Archivo renombrado: ..\reute\reuters\training\10737 -> ..\reute\reuters\training\10737.txt
# Archivo renombrado: ..\reute\reuters\training\10738 -> ..\reute\reuters\training\10738.txt
# Archivo renombrado: ..\reute\reuters\training\1074 -> ..\reute\reuters\training\1074.txt
# Archivo renombrado: ..\reute\reuters\training\10742 -> ..\reute\reuters\training\10742.txt
# Archivo renombrado: ..\reute\reuters\training\10743 -> ..\reute\reuters\training\10743.txt
# Archivo renombrado: ..\reute\reuters\training\10744 -> ..\reute\reuters\training\10744.txt
# Archivo renombrado: ..\reute\reuters\training\10746 -> ..\reute\reuters\training\10746.txt
# Archivo renombrado: ..\reute\reuters\training\10748 -> ..\reute\reuters\training\10748.txt
# Archivo renombrado: ..\reute\reuters\training\10749 -> ..\reute\reuters\training\10749.txt
# Archivo renombrado: ..\reute\reuters\training\10750 -> ..\reute\reuters\training\10750.txt
# Archivo renombrado: ..\reute\reuters\training\10751 -> ..\reute\reuters\training\10751.txt
# Archivo renombrado: ..\reute\reuters\training\10752 -> ..\reute\reuters\training\10752.txt
# Archivo renombrado: ..\reute\reuters\training\10754 -> ..\reute\reuters\training\10754.txt
# Archivo renombrado: ..\reute\reuters\training\10755 -> ..\reute\reuters\training\10755.txt
# Archivo renombrado: ..\reute\reuters\training\10756 -> ..\reute\reuters\training\10756.txt
# Archivo renombrado: ..\reute\reuters\training\10757 -> ..\reute\reuters\training\10757.txt
# Archivo renombrado: ..\reute\reuters\training\10758 -> ..\reute\reuters\training\10758.txt
# Archivo renombrado: ..\reute\reuters\training\1076 -> ..\reute\reuters\training\1076.txt
# Archivo renombrado: ..\reute\reuters\training\10760 -> ..\reute\reuters\training\10760.txt
# Archivo renombrado: ..\reute\reuters\training\10762 -> ..\reute\reuters\training\10762.txt
# Archivo renombrado: ..\reute\reuters\training\10766 -> ..\reute\reuters\training\10766.txt
# Archivo renombrado: ..\reute\reuters\training\10767 -> ..\reute\reuters\training\10767.txt
# Archivo renombrado: ..\reute\reuters\training\10768 -> ..\reute\reuters\training\10768.txt
# Archivo renombrado: ..\reute\reuters\training\10769 -> ..\reute\reuters\training\10769.txt
# Archivo renombrado: ..\reute\reuters\training\1077 -> ..\reute\reuters\training\1077.txt
# Archivo renombrado: ..\reute\reuters\training\10770 -> ..\reute\reuters\training\10770.txt
# Archivo renombrado: ..\reute\reuters\training\10771 -> ..\reute\reuters\training\10771.txt
# Archivo renombrado: ..\reute\reuters\training\10773 -> ..\reute\reuters\training\10773.txt
# Archivo renombrado: ..\reute\reuters\training\10774 -> ..\reute\reuters\training\10774.txt
# Archivo renombrado: ..\reute\reuters\training\10779 -> ..\reute\reuters\training\10779.txt
# Archivo renombrado: ..\reute\reuters\training\1078 -> ..\reute\reuters\training\1078.txt
# Archivo renombrado: ..\reute\reuters\training\10780 -> ..\reute\reuters\training\10780.txt
# Archivo renombrado: ..\reute\reuters\training\10781 -> ..\reute\reuters\training\10781.txt
# Archivo renombrado: ..\reute\reuters\training\10782 -> ..\reute\reuters\training\10782.txt
# Archivo renombrado: ..\reute\reuters\training\10784 -> ..\reute\reuters\training\10784.txt
# Archivo renombrado: ..\reute\reuters\training\10786 -> ..\reute\reuters\training\10786.txt
# Archivo renombrado: ..\reute\reuters\training\10787 -> ..\reute\reuters\training\10787.txt
# Archivo renombrado: ..\reute\reuters\training\10788 -> ..\reute\reuters\training\10788.txt
# Archivo renombrado: ..\reute\reuters\training\1079 -> ..\reute\reuters\training\1079.txt
# Archivo renombrado: ..\reute\reuters\training\10790 -> ..\reute\reuters\training\10790.txt
# Archivo renombrado: ..\reute\reuters\training\10794 -> ..\reute\reuters\training\10794.txt
# Archivo renombrado: ..\reute\reuters\training\10796 -> ..\reute\reuters\training\10796.txt
# Archivo renombrado: ..\reute\reuters\training\10797 -> ..\reute\reuters\training\10797.txt
# Archivo renombrado: ..\reute\reuters\training\108 -> ..\reute\reuters\training\108.txt
# Archivo renombrado: ..\reute\reuters\training\1080 -> ..\reute\reuters\training\1080.txt
# Archivo renombrado: ..\reute\reuters\training\10803 -> ..\reute\reuters\training\10803.txt
# Archivo renombrado: ..\reute\reuters\training\10804 -> ..\reute\reuters\training\10804.txt
# Archivo renombrado: ..\reute\reuters\training\10805 -> ..\reute\reuters\training\10805.txt
# Archivo renombrado: ..\reute\reuters\training\10807 -> ..\reute\reuters\training\10807.txt
# Archivo renombrado: ..\reute\reuters\training\10808 -> ..\reute\reuters\training\10808.txt
# Archivo renombrado: ..\reute\reuters\training\10809 -> ..\reute\reuters\training\10809.txt
# Archivo renombrado: ..\reute\reuters\training\10811 -> ..\reute\reuters\training\10811.txt
# Archivo renombrado: ..\reute\reuters\training\10815 -> ..\reute\reuters\training\10815.txt
# Archivo renombrado: ..\reute\reuters\training\10816 -> ..\reute\reuters\training\10816.txt
# Archivo renombrado: ..\reute\reuters\training\10817 -> ..\reute\reuters\training\10817.txt
# Archivo renombrado: ..\reute\reuters\training\1082 -> ..\reute\reuters\training\1082.txt
# Archivo renombrado: ..\reute\reuters\training\10822 -> ..\reute\reuters\training\10822.txt
# ...
# Archivo renombrado: ..\reute\reuters\test\21234 -> ..\reute\reuters\test\21234.txt
# Archivo renombrado: ..\reute\reuters\test\21236 -> ..\reute\reuters\test\21236.txt
# Archivo renombrado: ..\reute\reuters\test\21237 -> ..\reute\reuters\test\21237.txt
# Archivo renombrado: ..\reute\reuters\test\21238 -> ..\reute\reuters\test\21238.txt
# Archivo renombrado: ..\reute\reuters\test\21240 -> ..\reute\reuters\test\21240.txt
# Archivo renombrado: ..\reute\reuters\test\21242 -> ..\reute\reuters\test\21242.txt
# Archivo renombrado: ..\reute\reuters\test\21243 -> ..\reute\reuters\test\21243.txt
# Archivo renombrado: ..\reute\reuters\test\21244 -> ..\reute\reuters\test\21244.txt
# Archivo renombrado: ..\reute\reuters\test\21245 -> ..\reute\reuters\test\21245.txt
# Archivo renombrado: ..\reute\reuters\test\21248 -> ..\reute\reuters\test\21248.txt
# Archivo renombrado: ..\reute\reuters\test\21251 -> ..\reute\reuters\test\21251.txt
# Archivo renombrado: ..\reute\reuters\test\21252 -> ..\reute\reuters\test\21252.txt
# Archivo renombrado: ..\reute\reuters\test\21253 -> ..\reute\reuters\test\21253.txt
# Archivo renombrado: ..\reute\reuters\test\21255 -> ..\reute\reuters\test\21255.txt
# Archivo renombrado: ..\reute\reuters\test\21256 -> ..\reute\reuters\test\21256.txt
# Archivo renombrado: ..\reute\reuters\test\21257 -> ..\reute\reuters\test\21257.txt
# Archivo renombrado: ..\reute\reuters\test\21259 -> ..\reute\reuters\test\21259.txt
# Archivo renombrado: ..\reute\reuters\test\21260 -> ..\reute\reuters\test\21260.txt
# Archivo renombrado: ..\reute\reuters\test\21261 -> ..\reute\reuters\test\21261.txt
# Archivo renombrado: ..\reute\reuters\test\21262 -> ..\reute\reuters\test\21262.txt
# Archivo renombrado: ..\reute\reuters\test\21264 -> ..\reute\reuters\test\21264.txt
# Archivo renombrado: ..\reute\reuters\test\21265 -> ..\reute\reuters\test\21265.txt
# Archivo renombrado: ..\reute\reuters\test\21266 -> ..\reute\reuters\test\21266.txt
# Archivo renombrado: ..\reute\reuters\test\21267 -> ..\reute\reuters\test\21267.txt
# Archivo renombrado: ..\reute\reuters\test\21271 -> ..\reute\reuters\test\21271.txt
# Archivo renombrado: ..\reute\reuters\test\21272 -> ..\reute\reuters\test\21272.txt
# Archivo renombrado: ..\reute\reuters\test\21274 -> ..\reute\reuters\test\21274.txt
# Archivo renombrado: ..\reute\reuters\test\21275 -> ..\reute\reuters\test\21275.txt
# Archivo renombrado: ..\reute\reuters\test\21277 -> ..\reute\reuters\test\21277.txt
# Archivo renombrado: ..\reute\reuters\test\21278 -> ..\reute\reuters\test\21278.txt
# Archivo renombrado: ..\reute\reuters\test\21281 -> ..\reute\reuters\test\21281.txt
# Archivo renombrado: ..\reute\reuters\test\21282 -> ..\reute\reuters\test\21282.txt
# Archivo renombrado: ..\reute\reuters\test\21283 -> ..\reute\reuters\test\21283.txt
# Archivo renombrado: ..\reute\reuters\test\21285 -> ..\reute\reuters\test\21285.txt
# Archivo renombrado: ..\reute\reuters\test\21286 -> ..\reute\reuters\test\21286.txt
# Archivo renombrado: ..\reute\reuters\test\21287 -> ..\reute\reuters\test\21287.txt
# Archivo renombrado: ..\reute\reuters\test\21291 -> ..\reute\reuters\test\21291.txt
# Archivo renombrado: ..\reute\reuters\test\21292 -> ..\reute\reuters\test\21292.txt
# Archivo renombrado: ..\reute\reuters\test\21293 -> ..\reute\reuters\test\21293.txt
# Archivo renombrado: ..\reute\reuters\test\21295 -> ..\reute\reuters\test\21295.txt
# Archivo renombrado: ..\reute\reuters\test\21297 -> ..\reute\reuters\test\21297.txt
# Archivo renombrado: ..\reute\reuters\test\21298 -> ..\reute\reuters\test\21298.txt
# Archivo renombrado: ..\reute\reuters\test\21300 -> ..\reute\reuters\test\21300.txt
# Archivo renombrado: ..\reute\reuters\test\21301 -> ..\reute\reuters\test\21301.txt
# Archivo renombrado: ..\reute\reuters\test\21302 -> ..\reute\reuters\test\21302.txt
# Archivo renombrado: ..\reute\reuters\test\21303 -> ..\reute\reuters\test\21303.txt
# Archivo renombrado: ..\reute\reuters\test\21307 -> ..\reute\reuters\test\21307.txt
# Archivo renombrado: ..\reute\reuters\test\21308 -> ..\reute\reuters\test\21308.txt
# Archivo renombrado: ..\reute\reuters\test\21314 -> ..\reute\reuters\test\21314.txt
# Archivo renombrado: ..\reute\reuters\test\21315 -> ..\reute\reuters\test\21315.txt
# Archivo renombrado: ..\reute\reuters\test\21318 -> ..\reute\reuters\test\21318.txt
# Archivo renombrado: ..\reute\reuters\test\21319 -> ..\reute\reuters\test\21319.txt
# Archivo renombrado: ..\reute\reuters\test\21321 -> ..\reute\reuters\test\21321.txt
# Archivo renombrado: ..\reute\reuters\test\21322 -> ..\reute\reuters\test\21322.txt
# Archivo renombrado: ..\reute\reuters\test\21323 -> ..\reute\reuters\test\21323.txt
# Archivo renombrado: ..\reute\reuters\test\21324 -> ..\reute\reuters\test\21324.txt
# Archivo renombrado: ..\reute\reuters\test\21325 -> ..\reute\reuters\test\21325.txt
# Archivo renombrado: ..\reute\reuters\test\21330 -> ..\reute\reuters\test\21330.txt
# Archivo renombrado: ..\reute\reuters\test\21331 -> ..\reute\reuters\test\21331.txt
# Archivo renombrado: ..\reute\reuters\test\21333 -> ..\reute\reuters\test\21333.txt
# Archivo renombrado: ..\reute\reuters\test\21336 -> ..\reute\reuters\test\21336.txt
# Archivo renombrado: ..\reute\reuters\test\21337 -> ..\reute\reuters\test\21337.txt
# Archivo renombrado: ..\reute\reuters\test\21339 -> ..\reute\reuters\test\21339.txt
# Archivo renombrado: ..\reute\reuters\test\21342 -> ..\reute\reuters\test\21342.txt
# Archivo renombrado: ..\reute\reuters\test\21343 -> ..\reute\reuters\test\21343.txt
# Archivo renombrado: ..\reute\reuters\test\21346 -> ..\reute\reuters\test\21346.txt
# Archivo renombrado: ..\reute\reuters\test\21350 -> ..\reute\reuters\test\21350.txt
# Archivo renombrado: ..\reute\reuters\test\21352 -> ..\reute\reuters\test\21352.txt
# Archivo renombrado: ..\reute\reuters\test\21354 -> ..\reute\reuters\test\21354.txt
# Archivo renombrado: ..\reute\reuters\test\21356 -> ..\reute\reuters\test\21356.txt
# Archivo renombrado: ..\reute\reuters\test\21357 -> ..\reute\reuters\test\21357.txt
# Archivo renombrado: ..\reute\reuters\test\21358 -> ..\reute\reuters\test\21358.txt
# Archivo renombrado: ..\reute\reuters\test\21359 -> ..\reute\reuters\test\21359.txt
# Archivo renombrado: ..\reute\reuters\test\21360 -> ..\reute\reuters\test\21360.txt
# Archivo renombrado: ..\reute\reuters\test\21362 -> ..\reute\reuters\test\21362.txt
# Archivo renombrado: ..\reute\reuters\test\21363 -> ..\reute\reuters\test\21363.txt
# Archivo renombrado: ..\reute\reuters\test\21367 -> ..\reute\reuters\test\21367.txt
# Archivo renombrado: ..\reute\reuters\test\21368 -> ..\reute\reuters\test\21368.txt
# Archivo renombrado: ..\reute\reuters\test\21369 -> ..\reute\reuters\test\21369.txt
# Archivo renombrado: ..\reute\reuters\test\21371 -> ..\reute\reuters\test\21371.txt
# Archivo renombrado: ..\reute\reuters\test\21372 -> ..\reute\reuters\test\21372.txt
# Archivo renombrado: ..\reute\reuters\test\21373 -> ..\reute\reuters\test\21373.txt
# Archivo renombrado: ..\reute\reuters\test\21375 -> ..\reute\reuters\test\21375.txt
# Archivo renombrado: ..\reute\reuters\test\21376 -> ..\reute\reuters\test\21376.txt
# Archivo renombrado: ..\reute\reuters\test\21378 -> ..\reute\reuters\test\21378.txt
# Archivo renombrado: ..\reute\reuters\test\21380 -> ..\reute\reuters\test\21380.txt
# Archivo renombrado: ..\reute\reuters\test\21382 -> ..\reute\reuters\test\21382.txt
# Archivo renombrado: ..\reute\reuters\test\21385 -> ..\reute\reuters\test\21385.txt
# Archivo renombrado: ..\reute\reuters\test\21386 -> ..\reute\reuters\test\21386.txt
# Archivo renombrado: ..\reute\reuters\test\21387 -> ..\reute\reuters\test\21387.txt
# Archivo renombrado: ..\reute\reuters\test\21388 -> ..\reute\reuters\test\21388.txt
# Archivo renombrado: ..\reute\reuters\test\21391 -> ..\reute\reuters\test\21391.txt
# Archivo renombrado: ..\reute\reuters\test\21392 -> ..\reute\reuters\test\21392.txt
# Archivo renombrado: ..\reute\reuters\test\21393 -> ..\reute\reuters\test\21393.txt
# Archivo renombrado: ..\reute\reuters\test\21394 -> ..\reute\reuters\test\21394.txt
# Archivo renombrado: ..\reute\reuters\test\21401 -> ..\reute\reuters\test\21401.txt
# Archivo renombrado: ..\reute\reuters\test\21403 -> ..\reute\reuters\test\21403.txt
# Archivo renombrado: ..\reute\reuters\test\21404 -> ..\reute\reuters\test\21404.txt
# Archivo renombrado: ..\reute\reuters\test\21405 -> ..\reute\reuters\test\21405.txt
# Archivo renombrado: ..\reute\reuters\test\21406 -> ..\reute\reuters\test\21406.txt
# Archivo renombrado: ..\reute\reuters\test\21408 -> ..\reute\reuters\test\21408.txt
# Archivo renombrado: ..\reute\reuters\test\21410 -> ..\reute\reuters\test\21410.txt
# Archivo renombrado: ..\reute\reuters\test\21411 -> ..\reute\reuters\test\21411.txt
# Archivo renombrado: ..\reute\reuters\test\21412 -> ..\reute\reuters\test\21412.txt
# Archivo renombrado: ..\reute\reuters\test\21413 -> ..\reute\reuters\test\21413.txt
# Archivo renombrado: ..\reute\reuters\test\21414 -> ..\reute\reuters\test\21414.txt
# Archivo renombrado: ..\reute\reuters\test\21415 -> ..\reute\reuters\test\21415.txt
# Archivo renombrado: ..\reute\reuters\test\21416 -> ..\reute\reuters\test\21416.txt
# Archivo renombrado: ..\reute\reuters\test\21417 -> ..\reute\reuters\test\21417.txt
# Archivo renombrado: ..\reute\reuters\test\21419 -> ..\reute\reuters\test\21419.txt
# Archivo renombrado: ..\reute\reuters\test\21421 -> ..\reute\reuters\test\21421.txt
# Archivo renombrado: ..\reute\reuters\test\21423 -> ..\reute\reuters\test\21423.txt
# Archivo renombrado: ..\reute\reuters\test\21427 -> ..\reute\reuters\test\21427.txt
# Archivo renombrado: ..\reute\reuters\test\21429 -> ..\reute\reuters\test\21429.txt
# Archivo renombrado: ..\reute\reuters\test\21430 -> ..\reute\reuters\test\21430.txt
# Archivo renombrado: ..\reute\reuters\test\21431 -> ..\reute\reuters\test\21431.txt
# Archivo renombrado: ..\reute\reuters\test\21435 -> ..\reute\reuters\test\21435.txt
# Archivo renombrado: ..\reute\reuters\test\21436 -> ..\reute\reuters\test\21436.txt
# Archivo renombrado: ..\reute\reuters\test\21437 -> ..\reute\reuters\test\21437.txt
# Archivo renombrado: ..\reute\reuters\test\21440 -> ..\reute\reuters\test\21440.txt
# Archivo renombrado: ..\reute\reuters\test\21441 -> ..\reute\reuters\test\21441.txt
# Archivo renombrado: ..\reute\reuters\test\21443 -> ..\reute\reuters\test\21443.txt
# Archivo renombrado: ..\reute\reuters\test\21447 -> ..\reute\reuters\test\21447.txt
# Archivo renombrado: ..\reute\reuters\test\21448 -> ..\reute\reuters\test\21448.txt
# Archivo renombrado: ..\reute\reuters\test\21451 -> ..\reute\reuters\test\21451.txt
# Archivo renombrado: ..\reute\reuters\test\21453 -> ..\reute\reuters\test\21453.txt
# Archivo renombrado: ..\reute\reuters\test\21454 -> ..\reute\reuters\test\21454.txt
# Archivo renombrado: ..\reute\reuters\test\21455 -> ..\reute\reuters\test\21455.txt
# Archivo renombrado: ..\reute\reuters\test\21459 -> ..\reute\reuters\test\21459.txt
# Archivo renombrado: ..\reute\reuters\test\21460 -> ..\reute\reuters\test\21460.txt
# Archivo renombrado: ..\reute\reuters\test\21462 -> ..\reute\reuters\test\21462.txt
# Archivo renombrado: ..\reute\reuters\test\21465 -> ..\reute\reuters\test\21465.txt
# Archivo renombrado: ..\reute\reuters\test\21466 -> ..\reute\reuters\test\21466.txt
# Archivo renombrado: ..\reute\reuters\test\21468 -> ..\reute\reuters\test\21468.txt
# Archivo renombrado: ..\reute\reuters\test\21469 -> ..\reute\reuters\test\21469.txt
# Archivo renombrado: ..\reute\reuters\test\21473 -> ..\reute\reuters\test\21473.txt
# Archivo renombrado: ..\reute\reuters\test\21474 -> ..\reute\reuters\test\21474.txt
# Archivo renombrado: ..\reute\reuters\test\21475 -> ..\reute\reuters\test\21475.txt
# Archivo renombrado: ..\reute\reuters\test\21477 -> ..\reute\reuters\test\21477.txt
# Archivo renombrado: ..\reute\reuters\test\21478 -> ..\reute\reuters\test\21478.txt
# Archivo renombrado: ..\reute\reuters\test\21479 -> ..\reute\reuters\test\21479.txt
# Archivo renombrado: ..\reute\reuters\test\21480 -> ..\reute\reuters\test\21480.txt
# Archivo renombrado: ..\reute\reuters\test\21482 -> ..\reute\reuters\test\21482.txt
# Archivo renombrado: ..\reute\reuters\test\21484 -> ..\reute\reuters\test\21484.txt
# Archivo renombrado: ..\reute\reuters\test\21485 -> ..\reute\reuters\test\21485.txt
# Archivo renombrado: ..\reute\reuters\test\21486 -> ..\reute\reuters\test\21486.txt
# Archivo renombrado: ..\reute\reuters\test\21488 -> ..\reute\reuters\test\21488.txt
# Archivo renombrado: ..\reute\reuters\test\21489 -> ..\reute\reuters\test\21489.txt
# Archivo renombrado: ..\reute\reuters\test\21490 -> ..\reute\reuters\test\21490.txt
# Archivo renombrado: ..\reute\reuters\test\21492 -> ..\reute\reuters\test\21492.txt
# Archivo renombrado: ..\reute\reuters\test\21493 -> ..\reute\reuters\test\21493.txt
# Archivo renombrado: ..\reute\reuters\test\21496 -> ..\reute\reuters\test\21496.txt
# Archivo renombrado: ..\reute\reuters\test\21497 -> ..\reute\reuters\test\21497.txt
# Archivo renombrado: ..\reute\reuters\test\21501 -> ..\reute\reuters\test\21501.txt
# Archivo renombrado: ..\reute\reuters\test\21502 -> ..\reute\reuters\test\21502.txt
# Archivo renombrado: ..\reute\reuters\test\21503 -> ..\reute\reuters\test\21503.txt
# Archivo renombrado: ..\reute\reuters\test\21506 -> ..\reute\reuters\test\21506.txt
# Archivo renombrado: ..\reute\reuters\test\21508 -> ..\reute\reuters\test\21508.txt
# Archivo renombrado: ..\reute\reuters\test\21510 -> ..\reute\reuters\test\21510.txt
# Archivo renombrado: ..\reute\reuters\test\21511 -> ..\reute\reuters\test\21511.txt
# Archivo renombrado: ..\reute\reuters\test\21512 -> ..\reute\reuters\test\21512.txt
# Archivo renombrado: ..\reute\reuters\test\21517 -> ..\reute\reuters\test\21517.txt
# Archivo renombrado: ..\reute\reuters\test\21519 -> ..\reute\reuters\test\21519.txt
# Archivo renombrado: ..\reute\reuters\test\21521 -> ..\reute\reuters\test\21521.txt
# Archivo renombrado: ..\reute\reuters\test\21523 -> ..\reute\reuters\test\21523.txt
# Archivo renombrado: ..\reute\reuters\test\21525 -> ..\reute\reuters\test\21525.txt
# Archivo renombrado: ..\reute\reuters\test\21526 -> ..\reute\reuters\test\21526.txt
# Archivo renombrado: ..\reute\reuters\test\21530 -> ..\reute\reuters\test\21530.txt
# Archivo renombrado: ..\reute\reuters\test\21532 -> ..\reute\reuters\test\21532.txt
# Archivo renombrado: ..\reute\reuters\test\21535 -> ..\reute\reuters\test\21535.txt
# Archivo renombrado: ..\reute\reuters\test\21536 -> ..\reute\reuters\test\21536.txt
# Archivo renombrado: ..\reute\reuters\test\21538 -> ..\reute\reuters\test\21538.txt
# Archivo renombrado: ..\reute\reuters\test\21539 -> ..\reute\reuters\test\21539.txt
# Archivo renombrado: ..\reute\reuters\test\21541 -> ..\reute\reuters\test\21541.txt
# Archivo renombrado: ..\reute\reuters\test\21542 -> ..\reute\reuters\test\21542.txt
# Archivo renombrado: ..\reute\reuters\test\21550 -> ..\reute\reuters\test\21550.txt
# Archivo renombrado: ..\reute\reuters\test\21551 -> ..\reute\reuters\test\21551.txt
# Archivo renombrado: ..\reute\reuters\test\21553 -> ..\reute\reuters\test\21553.txt
# Archivo renombrado: ..\reute\reuters\test\21555 -> ..\reute\reuters\test\21555.txt
# Archivo renombrado: ..\reute\reuters\test\21556 -> ..\reute\reuters\test\21556.txt
# Archivo renombrado: ..\reute\reuters\test\21557 -> ..\reute\reuters\test\21557.txt
# Archivo renombrado: ..\reute\reuters\test\21561 -> ..\reute\reuters\test\21561.txt
# Archivo renombrado: ..\reute\reuters\test\21562 -> ..\reute\reuters\test\21562.txt
# Archivo renombrado: ..\reute\reuters\test\21565 -> ..\reute\reuters\test\21565.txt
# Archivo renombrado: ..\reute\reuters\test\21567 -> ..\reute\reuters\test\21567.txt
# Archivo renombrado: ..\reute\reuters\test\21568 -> ..\reute\reuters\test\21568.txt
# Archivo renombrado: ..\reute\reuters\test\21570 -> ..\reute\reuters\test\21570.txt
# Archivo renombrado: ..\reute\reuters\test\21571 -> ..\reute\reuters\test\21571.txt
# Archivo renombrado: ..\reute\reuters\test\21573 -> ..\reute\reuters\test\21573.txt
# Archivo renombrado: ..\reute\reuters\test\21574 -> ..\reute\reuters\test\21574.txt
# Archivo renombrado: ..\reute\reuters\test\21575 -> ..\reute\reuters\test\21575.txt
# Archivo renombrado: ..\reute\reuters\test\21576 -> ..\reute\reuters\test\21576.txt

# %%
def parse_cats_file(cats_file_path):
    """
    Lee el archivo 'cats.txt' y crea un diccionario que asocia a cada par de categorías
    (origen, nombre) su lista correspondiente de categorías.

    Parámetros:
        cats_file_path (str): Ruta al archivo 'cats.txt' que contiene las categorías y sus asociaciones.

    Retorna:
        dict: Un diccionario donde las claves son tuplas (origen, nombre) y los valores son las categorías asociadas como cadenas de texto.
    
    """
    categories = {}
    with open(cats_file_path, 'r', encoding='utf-8') as f:
        for line in f:
            parts = line.strip().split()  # Dividimos cada línea por espacios
            origin_and_name = parts[0]  # Tomamos la primera parte (origen/nombre)
            origin, name = origin_and_name.split('/')  # Separamos origen y nombre por '/'
            category_list = " ".join(parts[1:])  # El resto son las categorías asociadas
            categories[(origin, name)] = category_list  # Guardamos en el diccionario
    return categories

# %%
def extract_document_info(folder_path, origin, categories_dict):
    """
    Extrae la información relevante de los documentos dentro de una carpeta.

    La función recorre todos los archivos de texto (.txt) dentro de una carpeta especificada, lee su contenido y extrae el título, 
    el contenido y la categoría asociada a cada documento, la cual se obtiene del diccionario de categorías proporcionado.

    Parámetros:
        folder_path (str): Ruta a la carpeta que contiene los documentos de texto.
        origin (str): El origen del documento, utilizado para buscar la categoría correspondiente en el diccionario.
        categories_dict (dict): Diccionario que asocia a cada par (origen, nombre de archivo) con su categoría.

    Retorna:
        list: Una lista de diccionarios, cada uno con la información de un documento (nombre, título, contenido, origen y categoría).

    """
    documents_data = []  # Lista para almacenar los datos de los documentos procesados

    # Recorrer todos los archivos en la carpeta
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)  # Obtener la ruta completa del archivo

        # Verificar que el archivo sea un archivo de texto (.txt)
        if os.path.isfile(file_path) and filename.endswith('.txt'):
            
            # Abrir el archivo y leer su contenido
            with open(file_path, 'r', encoding='utf-8', errors='replace') as f:
                lines = f.readlines()  # Leer todas las líneas del archivo

                # Extraer el título (primera línea del archivo) y el contenido (resto del archivo)
                title = lines[0].strip() if lines else ''  # Asignar título si el archivo no está vacío
                content = "".join(lines[1:]).strip()  # Unir el resto de las líneas para el contenido

                # Buscar la categoría del documento en el diccionario usando el origen y el nombre del archivo (sin extensión)
                category = categories_dict.get((origin, filename.split('.')[0]), '')

                # Añadir la información del documento a la lista
                documents_data.append({
                    'Nombre': filename.split('.')[0],  # El nombre del documento sin la extensión
                    'Titulo': title,  # El título extraído
                    'Contenido': content,  # El contenido extraído
                    'Origen': origin,  # El origen proporcionado
                    'Categoria': category  # La categoría obtenida del diccionario
                })
    
    # Devolver la lista con los datos de todos los documentos procesados
    return documents_data

# %% [markdown]
# ## 2.2. Preprocesamiento
# ### Objetivo: Limpiar y preparar los datos para su análisis.
# - Tareas:
#     - Extraer el contenido relevante de los documentos.
#     - Realizar limpieza de datos: eliminación de caracteres no deseados, normalización de texto, etc.
#     - Tokenización: dividir el texto en palabras o tokens.
#     - Eliminar stop words y aplicar stemming o lematización.

# %%
def clean_text(text):
    """
    Elimina caracteres no deseados y normaliza el texto

    La función realiza las siguientes tareas de preprocesamiento en el texto:
    - Convierte todo el texto a minúsculas.
    - Elimina la puntuación utilizando el módulo 'string.punctuation'.
    - Elimina los espacios iniciales y finales del texto.

    Parámetros:
        text (str): El texto que se va a limpiar.

    Retorna:
        str: El texto limpio y normalizado

    """
    text = text.lower()  # Convertir a minúsculas 
    text = text.translate(str.maketrans('', '', string.punctuation))  # Eliminar la puntuación
    text = text.strip()  # Eliminar espacios iniciales y finales
    return text

# %%
# Diccionario de normalización (abreviaturas a términos completos)
normalization_dict = {
    # Abreviaciones de países y regiones
    "usa": "united states",
    "u.s.": "united states",
    "uk": "united kingdom",
    "u.k.": "united kingdom",
    "eu": "european union",
    "e.u.": "european union",
    "br": "brazil",
    "aus": "australia",
    "can": "canada",
    "germany": "germany",
    "fr": "france",
    "ind": "india",
    "ita": "italy",
    "jpn": "japan",
    "mex": "mexico",
    "rus": "russia",
    "ch": "china",
    "nzl": "new zealand",
    "saf": "south africa",
    "saudi arabia": "saudi arabia",
    "singapore": "singapore",
    
    # Abreviaturas de organizaciones y empresas
    "bbc": "british broadcasting corporation",
    "cia": "central intelligence agency",
    "euroland": "european union",
    "opec": "organization of petroleum exporting countries",
    "world bank": "world bank",
    "imf": "international monetary fund",
    "fbi": "federal bureau of investigation",
    "un": "united nations",
    "nato": "north atlantic treaty organization",
    "wto": "world trade organization",
    "g7": "group of seven",
    "g20": "group of twenty",
    "nasdaq": "national association of securities dealers automated quotations",
    "nyse": "new york stock exchange",
    "ftse": "financial times stock exchange",
    "dow": "dow jones industrial average",
    "apple": "apple inc.",
    "google": "google inc.",
    "microsoft": "microsoft corporation",
    "amazon": "amazon.com, inc.",
    "facebook": "facebook, inc.",
    "tesla": "tesla, inc.",
    
    # Abreviaturas de títulos y personas
    "mr": "mister",
    "mrs": "missus",
    "ms": "miss",
    "dr": "doctor",
    "prof": "professor",
    "pres": "president",
    "govt": "government",
    "ceo": "chief executive officer",
    "cfo": "chief financial officer",
    "cto": "chief technology officer",
    "coo": "chief operating officer",
    
    # Abreviaturas de términos financieros y económicos
    "gdp": "gross domestic product",
    "gni": "gross national income",
    "fdi": "foreign direct investment",
    "npl": "non-performing loan",
    "loi": "letter of intent",
    "ipo": "initial public offering",
    "m&a": "mergers and acquisitions",
    "equity": "equity",
    "debt": "debt",
    "stock market": "stock market",
    "bonds": "bonds",
    "lbo": "leveraged buyout",
    "ebitda": "earnings before interest, taxes, depreciation, and amortization",
    "cash flow": "cash flow",
    "earnings": "earnings",
    "revenue": "revenue",
    
    # Abreviaturas de tecnología
    "it": "information technology",
    "ai": "artificial intelligence",
    "ml": "machine learning",
    "iot": "internet of things",
    "big data": "big data",
    "cloud computing": "cloud computing",
    "saas": "software as a service",
    "paas": "platform as a service",
    "dba": "database administrator",
    "cybersecurity": "cybersecurity",
    "vpn": "virtual private network",
    "url": "uniform resource locator",
    
    # Términos generales y otros
    "e.g.": "for example",
    "i.e.": "that is",
    "vs": "versus",
    "etc": "et cetera",
    "no.": "number",
    "p.m.": "prime minister",
    "b.c.": "before christ",
    "a.d.": "anno domini",
    "usd": "united states dollar",
    "eur": "euro",
    "gbp": "great british pound",
    "inr": "indian rupee",
    "jpy": "japanese yen",
    "myr": "malaysian ringgit",
    "czk": "czech koruna",
    "krw": "south korean won",
    "sgd": "singapore dollar",
    "chf": "swiss franc",
    "nzd": "new zealand dollar",
    "xrp": "ripple",
    "btc": "bitcoin",
    "eth": "ethereum",
    
    # Términos de agencias de noticias y eventos
    "reuters": "reuters news agency",
    "bloomberg": "bloomberg",
    "bbc": "british broadcasting corporation",
    "cnn": "cable news network",
    "ft": "financial times",
    "wsj": "wall street journal",
    "nytimes": "new york times",
    "forbes": "forbes magazine",
    "cnbc": "cnbc",
    "wsj": "wall street journal",
    "ft": "financial times",
    
    # Otras abreviaturas comunes
    "inc.": "incorporated",
    "llc": "limited liability company",
    "co.": "company",
    "corp.": "corporation",
    "ltd": "limited",
    "co-op": "cooperative",
    "univ": "university",
    "dept": "department",
    "edu": "education",
    "gov": "government",
    "yr": "year",
    "mo": "month",
    "wks": "weeks",
    "hrs": "hours",
    "min": "minutes",
    "sec": "seconds"
}

# %%
def normalize_text(text, normalization_dict):
    """
    Normaliza el texto reemplazando abreviaciones y términos por sus formas completas.
    
    Parámetros:
        text (str): El texto que se va a normalizar.
        normalization_dict (dict): Diccionario con abreviaciones y sus formas completas.
    
    Retorna:
        str: El texto normalizado.
    """
    words = text.split()  # Separa el texto en palabras
    normalized_words = [normalization_dict.get(word, word) for word in words]  # Reemplaza según el diccionario
    return " ".join(normalized_words)  # Devuelve el texto normalizado

# %%
def preprocess_text(content, normalization_dict):
    """ 
    Realiza la limpieza, tokenización, eliminación de stopwords, stemming y normalización del texto.

    La función aplica una serie de pasos de preprocesamiento al texto:
    1. Limpieza del texto: elimina caracteres no deseados y normaliza el texto.
    2. Tokenización: divide el texto en palabras o tokens.
    3. Eliminación de stopwords: filtra las palabras irrelevantes.
    4. Aplicación de stemming: reduce las palabras a su raíz.
    5. Normalización: reemplaza abreviaciones y términos por sus formas completas.

    Parámetros:
        content (str): El texto que se va a preprocesar.
        normalization_dict (dict): Diccionario con abreviaciones y sus formas completas.

    Retorna:
        str: El texto preprocesado, con las palabras lematizadas, sin stopwords, normalizado y listo para el análisis.

    """
    # Paso 1: Limpieza de texto - Se normaliza el texto eliminando puntuación y convirtiendo a minúsculas.
    cleaned_text = clean_text(content)
    
    # Paso 2: Tokenización - Dividimos el texto limpio en palabras o tokens.
    tokens = word_tokenize(cleaned_text)
    
    # Paso 3: Eliminación de stopwords - Eliminamos las palabras comunes y sin significado relevante para el análisis.
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    
    # Paso 4: Stemming - Reducimos las palabras a su raíz usando el algoritmo PorterStemmer.
    stemmer = PorterStemmer()
    stemmed_tokens = [stemmer.stem(word) for word in tokens]
    
    # Paso 5: Reconstrucción del texto preprocesado - Unimos los tokens procesados en una cadena de texto.
    preprocessed_text = " ".join(stemmed_tokens)
    
    # Paso 6: Normalización - Reemplazamos abreviaciones y términos por sus formas completas usando el diccionario.
    normalized_text = normalize_text(preprocessed_text, normalization_dict)
    
    return normalized_text

# %%
# Preprocesamiento de documentos
def preprocess_documents(data):
    """
    Aplica preprocesamiento al contenido de cada documento en los datos.

    La función recorre cada documento en el conjunto de datos, preprocesando tanto el contenido 
    como el título del documento. El contenido y el título pasan por la función `preprocess_text` 
    para realizar limpieza, tokenización, eliminación de stopwords, stemming y normalización.

    Parámetros:
        data (list): Una lista de diccionarios donde cada diccionario representa un documento con claves 
                     como 'Contenido' (texto del documento) y 'Titulo' (título del documento).

    Retorna:
        list: La lista de documentos con los campos 'Contenido Preprocesado' y 'Titulo Preprocesado' 
              añadidos, que contienen el texto limpio y normalizado de cada documento.

    """
    # Recorremos cada documento en los datos para aplicar el preprocesamiento
    for doc in data:
        original_content = doc['Contenido']  # Extraemos el contenido original del documento
        preprocessed_content = preprocess_text(original_content, normalization_dict)  # Preprocesamos el contenido
        doc['Contenido Preprocesado'] = preprocessed_content  # Guardamos el contenido preprocesado

        original_title = doc['Titulo']  # Extraemos el título original del documento
        preprocessed_title = preprocess_text(original_title, normalization_dict)  # Preprocesamos el título
        doc['Titulo Preprocesado'] = preprocessed_title  # Guardamos el título preprocesado

    return data  # Devolvemos la lista de documentos con los campos preprocesados

# %%
# Rutas
training_dir = os.path.join(reuters_dir, "training")  # Ruta al directorio de entrenamiento
test_dir = os.path.join(reuters_dir, "test")  # Ruta al directorio de prueba
cats_file_path = os.path.join(reuters_dir, "cats.txt")  # Ruta al archivo de categorías

# Leer el archivo cats.txt para obtener las categorías
categories_dict = parse_cats_file(cats_file_path)  # Procesa el archivo cats.txt para obtener el diccionario de categorías

# Procesar carpetas training y test
training_data = extract_document_info(training_dir, "training", categories_dict)  # Extrae la información de los documentos en el directorio de entrenamiento
test_data = extract_document_info(test_dir, "test", categories_dict)  # Extrae la información de los documentos en el directorio de prueba

# Preprocesar el contenido de los documentos
all_data = training_data + test_data  # Combina los datos de entrenamiento y prueba
all_data = preprocess_documents(all_data)  # Aplica el preprocesamiento a todo el contenido de los documentos (títulos y cuerpos de los documentos)

# Guardar en un archivo Excel
df = pd.DataFrame(all_data)  # Convierte la lista de diccionarios en un DataFrame de pandas
output_excel_path = os.path.join(reuters_dir, "reuters_data_preprocessed.xlsx")  # Define la ruta de salida del archivo Excel
df.to_excel(output_excel_path, index=False)  # Guarda el DataFrame en un archivo Excel sin incluir el índice de filas

# %% [markdown]
# ## 2.3. Representacion de Datos en Espacio Vectorial
# ### Objetivo: Convertir los textos en una forma que los algoritmos puedan procesar.
# - Tareas:
#     - Utilizar técnicas como Bag ofWords (BoW), TF-IDF, yWord2Vec para vectorizar el texto.
#     - Evaluar las diferentes técnicas de vectorización.
#     - Documentar los métodos y resultados obtenidos.

# %%
# Ruta al archivo Excel preprocesado
input_excel_path = os.path.join(reuters_dir, "reuters_data_preprocessed.xlsx")  # Define la ruta donde se encuentra el archivo Excel con los datos preprocesados

# Leer el archivo Excel usando pandas
df = pd.read_excel(input_excel_path)  # Carga el archivo Excel en un DataFrame de pandas

# Seleccionar el contenido preprocesado
texts = df['Contenido Preprocesado'].fillna("").tolist()  # Extrae la columna 'Contenido Preprocesado', reemplaza valores nulos con cadenas vacías y convierte la columna a una lista de textos

# %%
# Bag of Words (BoW)
def bag_of_words(texts):
    """
    Convierte una lista de textos en una matriz de características utilizando el modelo Bag of Words (BoW).

    La función utiliza el `CountVectorizer` de scikit-learn para crear una representación numérica de los textos,
    donde cada columna corresponde a una palabra única (vocabulario) y cada fila representa un documento.

    Parámetros:
        texts (list): Lista de cadenas de texto que se van a convertir en una matriz BoW.

    Retorna:
        tuple: 
            - bow_matrix (sparse matrix): Matriz dispersa que representa los textos como vectores de frecuencia de palabras.
            - bow_features (array): Lista de palabras (características) que forman el vocabulario.
    """
    # Crear el vectorizador de palabras (BoW)
    vectorizer = CountVectorizer()  # Inicializa el CountVectorizer
    
    # Convertir los textos en una matriz de características BoW
    bow_matrix = vectorizer.fit_transform(texts)  # Ajusta el vectorizador a los textos y genera la matriz
    
    # Obtener las características (palabras) que forman el vocabulario
    bow_features = vectorizer.get_feature_names_out()  # Extrae las palabras del vocabulario
    
    # Imprimir el tamaño de la matriz BoW
    print(f"BoW: Matriz de tamaño {bow_matrix.shape}")  # Imprime las dimensiones de la matriz resultante
    
    return bow_matrix, bow_features  # Devuelve la matriz BoW y el vocabulario

# %%
# TF-IDF
def tf_idf(texts):
    """
    Convierte una lista de textos en una matriz de características utilizando el modelo TF-IDF (Term Frequency - Inverse Document Frequency).
    
    La función utiliza el `TfidfVectorizer` de scikit-learn para transformar los textos en una representación numérica, 
    donde cada columna corresponde a una palabra única del vocabulario, y cada fila representa un documento con un peso 
    que indica la importancia relativa de la palabra en el documento con respecto al corpus completo.

    Parámetros:
        texts (list): Lista de cadenas de texto que se van a convertir en una matriz TF-IDF.

    Retorna:
        tuple: 
            - tfidf_matrix (sparse matrix): Matriz dispersa que representa los textos como vectores de peso de palabras.
            - tfidf_features (array): Lista de palabras (características) que forman el vocabulario.
    """
    # Crear el vectorizador TF-IDF
    vectorizer = TfidfVectorizer()  # Inicializa el TfidfVectorizer
    
    # Convertir los textos en una matriz de características TF-IDF
    tfidf_matrix = vectorizer.fit_transform(texts)  # Ajusta el vectorizador a los textos y genera la matriz
    
    # Obtener las características (palabras) que forman el vocabulario
    tfidf_features = vectorizer.get_feature_names_out()  # Extrae las palabras del vocabulario
    
    # Imprimir el tamaño de la matriz TF-IDF
    print(f"TF-IDF: Matriz de tamaño {tfidf_matrix.shape}")  # Imprime las dimensiones de la matriz resultante
    
    return tfidf_matrix, tfidf_features  # Devuelve la matriz TF-IDF y el vocabulario

# %%
# Word2Vec
def word2vec(texts, vector_size=100, window=5, min_count=1):
    """
    Genera representaciones vectoriales de palabras utilizando el modelo Word2Vec.

    La función usa la biblioteca `gensim` para crear un modelo Word2Vec, que convierte cada palabra en los textos 
    proporcionados en un vector numérico de características, capturando las relaciones semánticas entre palabras.

    Parámetros:
        texts (list): Lista de cadenas de texto que serán tokenizadas (separadas en palabras) y procesadas.
        vector_size (int): Tamaño de los vectores de características para cada palabra. Default es 100.
        window (int): Número de palabras contextuales a considerar alrededor de cada palabra en el modelo. Default es 5.
        min_count (int): Número mínimo de apariciones de una palabra para ser incluida en el modelo. Default es 1.

    Retorna:
        word_vectors: Objeto `KeyedVectors` que contiene las representaciones vectoriales de las palabras.

    """
    # Tokenización: Se convierte cada texto en una lista de palabras (tokens).
    tokenized_texts = [text.split() for text in texts]  # Separa cada texto en palabras
    
    # Entrenamiento del modelo Word2Vec con los textos tokenizados.
    model = Word2Vec(sentences=tokenized_texts, vector_size=vector_size, window=window, min_count=min_count)  # Ajusta el modelo
    
    # Obtener los vectores de palabras entrenados.
    word_vectors = model.wv  # Extrae las representaciones vectoriales de las palabras
    
    # Imprimir el número de palabras y el tamaño de los vectores.
    print(f"Word2Vec: {len(word_vectors)} palabras representadas con vectores de tamaño {vector_size}")  # Muestra la cantidad de palabras
    
    return word_vectors  # Devuelve las representaciones vectoriales de las palabras

# %%
# Generar representaciones

# Paso 1: Aplicar el modelo Bag of Words (BoW) para convertir los textos en una matriz de frecuencias de palabras
bow_matrix, bow_features = bag_of_words(texts)  # Llama a la función bag_of_words para obtener la matriz BoW y las características

# Paso 2: Aplicar el modelo TF-IDF para convertir los textos en una matriz de pesos de palabras
tfidf_matrix, tfidf_features = tf_idf(texts)  # Llama a la función tf_idf para obtener la matriz TF-IDF y las características

# Paso 3: Aplicar el modelo Word2Vec para obtener representaciones vectoriales de las palabras
word_vectors = word2vec(texts)  # Llama a la función word2vec para generar los vectores de palabras
# Out:
# BoW: Matriz de tamaño (10788, 38329)
# TF-IDF: Matriz de tamaño (10788, 38329)
# Word2Vec: 38357 palabras representadas con vectores de tamaño 100

# %%
# Documentar resultados
# Se crea un diccionario para almacenar los resultados de cada técnica de representación
results = {
    "Técnica": ["Bag of Words", "TF-IDF", "Word2Vec"],  # Lista con los nombres de las técnicas aplicadas
    "Dimensión de Matriz": [bow_matrix.shape, tfidf_matrix.shape, len(word_vectors)],  # Tamaño de la matriz generada por cada técnica
    "Tamaño de Vocabulario": [len(bow_features), len(tfidf_features), len(word_vectors)]  # Número de características (palabras) en el vocabulario de cada técnica
}

# Crear DataFrame con resultados
# Se convierte el diccionario de resultados en un DataFrame de pandas para mejor visualización
results_df = pd.DataFrame(results)  # Crea un DataFrame con los resultados para fácil acceso y análisis

# %%
# Función para preprocesar la consulta
def preprocess_query(query, normalization_dict):
    """
    Aplica el preprocesamiento a la consulta, igual que se hace para el corpus.
    """
    preprocessed_query = preprocess_text(query, normalization_dict)  # Se usa el mismo preprocesamiento aplicado al corpus
    return preprocessed_query

# %%
# Función para medir el tiempo de ejecución de cada técnica
def evaluate_vectorization(query, normalization_dict, bow_vectorizer, tfidf_vectorizer, word2vec_model, num_runs=10):
    """
    Evalúa el tiempo de ejecución de cada técnica de vectorización (BoW, TF-IDF, Word2Vec) para la consulta dada,
    ejecutado múltiples veces para tomar un tiempo promedio.
    """
    # Preprocesar la consulta
    preprocessed_query = preprocess_query(query, normalization_dict)
    
    # Variables para almacenar los tiempos
    bow_times = []
    tfidf_times = []
    word2vec_times = []
    
    # Ejecutar las evaluaciones múltiples veces
    for _ in range(num_runs):
        # Evaluar con Bag of Words (BoW)
        start_time = time.time()
        bow_vector = bow_vectorizer.transform([preprocessed_query])  # Convertir consulta a BoW
        bow_times.append(time.time() - start_time)  # Medir tiempo
        
        # Evaluar con TF-IDF
        start_time = time.time()
        tfidf_vector = tfidf_vectorizer.transform([preprocessed_query])  # Convertir consulta a TF-IDF
        tfidf_times.append(time.time() - start_time)  # Medir tiempo
        
        # Evaluar con Word2Vec
        start_time = time.time()
        word2vec_vector = [word2vec_model[word] for word in preprocessed_query.split() if word in word2vec_model]  # Convertir consulta a Word2Vec
        word2vec_times.append(time.time() - start_time)  # Medir tiempo
    
    # Promedio de los tiempos
    avg_bow_time = np.mean(bow_times)
    avg_tfidf_time = np.mean(tfidf_times)
    avg_word2vec_time = np.mean(word2vec_times)
    
    # Mostrar los tiempos de ejecución promedio para cada técnica
    print(f"Tiempo promedio de ejecución para Bag of Words: {avg_bow_time:.8f} segundos")
    print(f"Tiempo promedio de ejecución para TF-IDF: {avg_tfidf_time:.8f} segundos")
    print(f"Tiempo promedio de ejecución para Word2Vec: {avg_word2vec_time:.8f} segundos")
    
    # Devolver los resultados promedio
    return {
        "BoW Time": avg_bow_time,
        "TF-IDF Time": avg_tfidf_time,
        "Word2Vec Time": avg_word2vec_time
    }

# %%
query = "the farmer-owned reserve national five-day"

# Inicializar los vectorizadores
bow_vectorizer = CountVectorizer()
tfidf_vectorizer = TfidfVectorizer()

# Ajustar los vectorizadores a los datos de entrenamiento 
bow_vectorizer.fit(texts)  # Ajusta BoW al corpus
tfidf_vectorizer.fit(texts)  # Ajusta TF-IDF al corpus

# Crear el modelo Word2Vec
tokenized_texts = [text.split() for text in texts]  # Tokenizar los textos
word2vec_model = Word2Vec(sentences=tokenized_texts, vector_size=100, window=5, min_count=1)

# Evaluar la consulta
results = evaluate_vectorization(query, normalization_dict, bow_vectorizer, tfidf_vectorizer, word2vec_model.wv, num_runs=10)

# Mostrar los resultados
print(results)
# Out:
# Tiempo promedio de ejecución para Bag of Words: 0.00000000 segundos
# Tiempo promedio de ejecución para TF-IDF: 0.00000000 segundos
# Tiempo promedio de ejecución para Word2Vec: 0.00000000 segundos
# {'BoW Time': 0.0, 'TF-IDF Time': 0.0, 'Word2Vec Time': 0.0}

# %% [markdown]
# ## 2.4. Indexación
# ### Objetivo: Crear un índice que permita búsquedas eficientes.
# - Tareas:
#     - Construir un índice invertido que mapee términos a documentos.
#     - Implementar y optimizar estructuras de datos para el índice.
#     - Documentar el proceso de construcción del índice.

# %%
def build_inverted_index(documents):
    """
    Construye un índice invertido que mapea términos a documentos.
    
    Parámetros:
        documents (list): Lista de diccionarios con los datos de los documentos.
    
    Retorna:
        dict: Índice invertido donde las claves son términos y los valores son listas de documentos.
    """
    # Crear un diccionario para el índice invertido donde cada término apunta a un conjunto de IDs de documentos.
    inverted_index = defaultdict(set)  # Usamos un set para evitar duplicados
    
    # Recorrer cada documento en la lista de documentos
    for doc in documents:
        doc_id = doc['Nombre']  # Obtener el ID único del documento
        content = doc['Contenido Preprocesado']  # Obtener el contenido preprocesado del documento
        terms = set(content.split())  # Tokenizar el contenido en términos únicos (sin repetir palabras)

        # Para cada término en el documento, agregar el ID del documento al índice invertido
        for term in terms:
            inverted_index[term].add(doc_id)  # Asociar el término con el documento correspondiente
    
    # Convertir los sets a listas para que el índice invertido sea más fácil de manejar
    return {term: list(doc_ids) for term, doc_ids in inverted_index.items()}  # Devolver el índice invertido como un diccionario

# %%
def save_inverted_index_to_excel(inverted_index, output_path):
    """
    Guarda el índice invertido en un archivo Excel para fácil visualización.
    
    Parámetros:
        inverted_index (dict): Índice invertido.
        output_path (str): Ruta del archivo Excel donde se guardará.
    """
    # Crear una lista de diccionarios con los términos y sus documentos correspondientes.
    # Cada diccionario tendrá el término y una cadena con los IDs de los documentos donde aparece ese término.
    index_data = [{"Término": term, "Documentos": ", ".join(map(str, doc_ids))} for term, doc_ids in inverted_index.items()]

    
    # Convertir la lista de diccionarios en un DataFrame de pandas para facilitar la exportación.
    df = pd.DataFrame(index_data)
    
    # Guardar el DataFrame en un archivo Excel sin incluir el índice de filas.
    df.to_excel(output_path, index=False)
    
    # Imprimir mensaje confirmando la ubicación del archivo guardado.
    print(f"Índice invertido guardado en: {output_path}")

# %%
# Seleccionar los datos preprocesados
documents = df.to_dict(orient='records')

# Construir índice invertido
inverted_index = build_inverted_index(documents)

# Guardar resultados en Excel
output_excel_path = os.path.join(reuters_dir, "inverted_index.xlsx")
save_inverted_index_to_excel(inverted_index, output_excel_path)

# Documentación del proceso
print("Índice invertido creado con éxito.")
print(f"Términos indexados: {len(inverted_index)}")
# Out:
# Índice invertido guardado en: ..\reute\reuters\inverted_index.xlsx
# Índice invertido creado con éxito.
# Términos indexados: 38357

# %% [markdown]
# ## 2.5. Diseño del Motor de Búsqueda
# ### Objetivo: Implementar la funcionalidad de búsqueda.
# - Tareas:
#     - Desarrollar la lógica para procesar consultas de usuarios.
#     - Utilizar algoritmos de similitud como similitud coseno o Jaccard.
#     - Desarrollar un algoritmo de ranking para ordenar los resultados.
#     - Documentar la arquitectura y los algoritmos utilizados.

# %%
# Preprocesamiento de consulta
def preprocess_query(query, stop_words):
    """
    Limpia y preprocesa la consulta ingresada por el usuario.
    
    Parámetros:
        query (str): La consulta ingresada por el usuario.
        stop_words (list): Lista de palabras vacías (stopwords) a eliminar de la consulta.

    Retorna:
        list: Lista de tokens filtrados y procesados de la consulta.
    """
    # Limpiar la consulta: convertir a minúsculas y eliminar puntuación
    query = query.lower().translate(str.maketrans('', '', string.punctuation))  

    # Tokenizar la consulta
    tokens = query.split()  

    # Eliminar las stop words
    tokens = [word for word in tokens if word not in stop_words]  

    return tokens  # Devuelve la lista de palabras procesadas

# Cargar datos del índice invertido y documentos
input_excel_path = os.path.join(reuters_dir, "reuters_data_preprocessed.xlsx")
df = pd.read_excel(input_excel_path)  # Lee el archivo Excel con los datos preprocesados

# Extraer los documentos y sus IDs
documents = df['Contenido Preprocesado'].tolist()  # Obtiene la lista de contenidos preprocesados
document_ids = df['Nombre'].tolist()  # Obtiene la lista de nombres de los documentos

# %%
# Vectorización con TF-IDF
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)

def search_query_cosine(query, tfidf_vectorizer, tfidf_matrix, document_ids, top_k=10):
    """
    Realiza una búsqueda utilizando similitud coseno.
    """
    query_vector = tfidf_vectorizer.transform([query])  # Vectorizar consulta
    cosine_similarities = cosine_similarity(query_vector, tfidf_matrix).flatten()
    
    # Ordenar documentos por similitud descendente
    ranked_indices = np.argsort(-cosine_similarities)[:top_k]
    results = [(document_ids[i], cosine_similarities[i]) for i in ranked_indices if cosine_similarities[i] > 0]
    return results

# %%
# Vectorización con TF-IDF
tfidf_vectorizer = TfidfVectorizer()  # Inicializa el vectorizador TF-IDF
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)  # Aplica el vectorizador a los documentos

def search_query_cosine(query, tfidf_vectorizer, tfidf_matrix, document_ids, top_k=10):
    """
    Realiza una búsqueda utilizando similitud coseno para encontrar los documentos más relevantes en función de una consulta.
    
    La función toma una consulta de texto y calcula su similitud coseno con los documentos preprocesados y vectorizados
    utilizando el modelo TF-IDF. Devuelve los documentos más similares junto con sus puntuaciones de similitud.
    
    Parámetros:
        query (str): La consulta de texto ingresada por el usuario.
        tfidf_vectorizer (TfidfVectorizer): El vectorizador TF-IDF previamente ajustado.
        tfidf_matrix (sparse matrix): La matriz de características de TF-IDF de los documentos.
        document_ids (list): Lista con los IDs de los documentos.
        top_k (int): Número de resultados más relevantes a devolver. Default es 10.
    
    Retorna:
        list: Una lista de tuplas donde cada tupla contiene un ID de documento y su puntuación de similitud coseno.
    """
    # Convertir la consulta a un vector TF-IDF
    query_vector = tfidf_vectorizer.transform([query])  

    # Calcular la similitud coseno entre la consulta y todos los documentos
    cosine_similarities = cosine_similarity(query_vector, tfidf_matrix).flatten()  

    # Ordenar los documentos por similitud coseno en orden descendente
    ranked_indices = np.argsort(-cosine_similarities)[:top_k]  

    # Filtrar los resultados y devolver solo aquellos con puntuación positiva
    results = [(document_ids[i], cosine_similarities[i]) for i in ranked_indices if cosine_similarities[i] > 0]
    
    return results  # Devuelve los documentos más similares junto con sus puntuaciones de similitud

# %%
def jaccard_similarity(query_tokens, doc_tokens):
    """
    Calcula la similitud de Jaccard entre la consulta y un documento.

    Parámetros:
        query_tokens (list): Lista de tokens (palabras) de la consulta preprocesada.
        doc_tokens (list): Lista de tokens (palabras) del documento preprocesado.

    Retorna:
        float: El valor de la similitud de Jaccard entre la consulta y el documento. Un valor entre 0 y 1,
               donde 1 significa que los conjuntos son idénticos y 0 significa que no comparten ningún término.
    """
    # Calcular la intersección de los conjuntos de tokens
    intersection = len(set(query_tokens).intersection(set(doc_tokens))) 

    # Calcular la unión de los conjuntos de tokens
    union = len(set(query_tokens).union(set(doc_tokens)))  

    # Retornar la similitud de Jaccard (intersección / unión)
    return intersection / union

# %%
def search_query_jaccard(query, documents, document_ids, top_k=10):
    """
    Realiza una búsqueda utilizando el coeficiente de Jaccard para encontrar los documentos más relevantes en función de una consulta.
    
    Parámetros:
        query (str): La consulta ingresada por el usuario, como una cadena de texto.
        documents (list): Lista de textos de los documentos preprocesados.
        document_ids (list): Lista de identificadores de los documentos correspondientes.
        top_k (int): Número de resultados más relevantes a devolver. El valor por defecto es 10.

    Retorna:
        list: Una lista de tuplas, donde cada tupla contiene un ID de documento y su puntuación de similitud de Jaccard.

    """
    results = []  # Lista para almacenar los resultados de similitud
    
    # Tokenizar la consulta en palabras
    query_tokens = query.split()
    
    # Iterar sobre cada documento y su ID correspondiente
    for doc_id, doc_content in zip(document_ids, documents):
        doc_tokens = doc_content.split()  # Tokenizar el contenido del documento
        score = jaccard_similarity(query_tokens, doc_tokens)  # Calcular la similitud de Jaccard entre consulta y documento
        
        # Si la similitud es mayor a 0, agregar el documento y su puntuación a los resultados
        if score > 0:
            results.append((doc_id, score))
    
    # Ordenar los resultados por la puntuación de similitud en orden descendente y seleccionar los primeros 'top_k' resultados
    results = sorted(results, key=lambda x: x[1], reverse=True)[:top_k]
    
    # Retornar los documentos más relevantes
    return results

# %%
def rank_results(results, method="cosine"):
    """
    Ordena los resultados de búsqueda según el método de clasificación especificado.
    
    Parámetros:
        results (list): Lista de tuplas, donde cada tupla contiene un ID de documento y su puntuación.
        method (str): El método de clasificación a usar.

    Retorna:
        list: La lista de resultados ordenada en orden descendente según las puntuaciones.

    """
    # Ordenar los resultados por la puntuación (segundo valor de cada tupla) en orden descendente
    return sorted(results, key=lambda x: x[1], reverse=True)

# %%
# Probar con una consulta
user_query = "BAHIA COCOA REVIEW"
preprocessed_query = " ".join(preprocess_query(user_query, set(stopwords.words('english'))))

# %%
# Búsqueda con similitud coseno
cosine_results = search_query_cosine(preprocessed_query, tfidf_vectorizer, tfidf_matrix, document_ids)
cosine_results_ranked = rank_results(cosine_results)

# Búsqueda con similitud Jaccard
jaccard_results = search_query_jaccard(preprocessed_query, documents, document_ids)
jaccard_results_ranked = rank_results(jaccard_results, method="jaccard")

# %%
# Mostrar resultados
print("Resultados con Cosine Similarity:", cosine_results_ranked, "\n")
print("Resultados con Jaccard Similarity:", jaccard_results_ranked)
# Out:
# Resultados con Cosine Similarity: [(10505, 0.3489240003908758), (20005, 0.3299154574278401), (5258, 0.3081624300184678), (17568, 0.2954369602819941), (10506, 0.2929586024193468), (9450, 0.2926443043511501), (1, 0.28596103888941893), (15095, 0.2815737227497522), (9953, 0.2800592086344812), (10760, 0.2727047868510829)]
#
# Resultados con Jaccard Similarity: [(10471, 0.1), (10491, 0.1), (21061, 0.1), (6068, 0.09090909090909091), (3190, 0.08333333333333333), (8326, 0.07142857142857142), (17733, 0.07142857142857142), (18221, 0.07142857142857142), (19358, 0.07142857142857142), (6873, 0.045454545454545456)]

# %% [markdown]
# ## 2.6. Evaluación del Sistema
# ### Objetivo: Medir la efectividad del sistema.
# - Tareas:
#     - Definir un conjunto de métricas de evaluación (precisión, recall, F1-score).
#     - Realizar pruebas utilizando el conjunto de prueba del corpus.
#     - Comparar el rendimiento de diferentes configuraciones del sistema.
#     - Documentar los resultados y análisis.

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# Función para calcular la similitud de Jaccard
def calculate_jaccard_similarity(query_terms, doc_terms):
    intersection = len(set(query_terms).intersection(set(doc_terms)))
    union = len(set(query_terms).union(set(doc_terms)))
    return intersection / union if union != 0 else 0

# Función para calcular la similitud de Coseno
def calculate_cosine_similarity(query_terms, doc_terms):
    vectorizer_terms = list(set(query_terms + doc_terms))
    query_vector = [1 if term in query_terms else 0 for term in vectorizer_terms]
    doc_vector = [1 if term in doc_terms else 0 for term in vectorizer_terms]
    return cosine_similarity([query_vector], [doc_vector])[0][0]

# Leer el índice invertido
inverted_index_path = r"../reute/reuters/inverted_index.xlsx"
inverted_index_df = pd.read_excel(inverted_index_path)

# Convertir los documentos a listas
inverted_index_df['Documentos'] = inverted_index_df['Documentos'].apply(
    lambda x: list(map(int, str(x).split(',')))
)

# Crear un diccionario del índice invertido para acceso rápido
inverted_index_dict = dict(zip(inverted_index_df['Término'], inverted_index_df['Documentos']))

# Función para buscar documentos relevantes en el índice invertido
def find_documents(query_terms, index_dict):
    relevant_docs = set()
    for term in query_terms:
        if term in index_dict:
            relevant_docs.update(index_dict[term])
    return list(relevant_docs)

# Función para obtener términos preprocesados de una consulta
def preprocess_query(query):
    return query.lower().split()  # Tokenización simple, ajustable según necesidades

# Función para calcular métricas
def calculate_metrics(results, relevant_docs, threshold=0.1):
    precision = {}
    recall = {}
    f1_scores = {}

    for query_id in results.keys():
        retrieved_docs = [doc for doc, sim in results[query_id] if sim >= threshold]
        relevant = relevant_docs.get(query_id, [])
        
        tp = len(set(retrieved_docs).intersection(set(relevant)))
        fp = len(set(retrieved_docs) - set(relevant))
        fn = len(set(relevant) - set(retrieved_docs))

        precision[query_id] = tp / (tp + fp) if (tp + fp) != 0 else 0
        recall[query_id] = tp / (tp + fn) if (tp + fn) != 0 else 0
        f1_scores[query_id] = (
            2 * precision[query_id] * recall[query_id] / (precision[query_id] + recall[query_id])
            if (precision[query_id] + recall[query_id]) != 0 else 0
        )
    return precision, recall, f1_scores

# Consultas de ejemplo
queries = {
    1: "trace",
    2: "februari water"
}

# Buscar documentos relevantes y calcular similitudes
results = {}
relevant_docs = {}

for query_id, query_text in queries.items():
    query_terms = preprocess_query(query_text)
    # Encontrar documentos relevantes en el índice invertido
    relevant_docs[query_id] = find_documents(query_terms, inverted_index_dict)

    # Calcular similitudes Jaccard y Coseno
    query_results = []
    for doc_id in relevant_docs[query_id]:
        doc_terms = []
        for term, docs in inverted_index_dict.items():
            if doc_id in docs:
                doc_terms.append(term)
        
        jaccard_sim = calculate_jaccard_similarity(query_terms, doc_terms)
        cosine_sim = calculate_cosine_similarity(query_terms, doc_terms)
        
        query_results.append((doc_id, max(jaccard_sim, cosine_sim)))  # Tomamos el máximo de ambas

    # Ordenar los resultados por la similitud en orden descendente
    results[query_id] = sorted(query_results, key=lambda x: x[1], reverse=True)

# Calcular métricas de evaluación con un umbral
precision, recall, f1_scores = calculate_metrics(results, relevant_docs, threshold=0.1)

# Mostrar resultados
for query_id in queries.keys():
    print(f"\nResultados para la consulta '{queries[query_id]}':")
    print(f"  Precisión: {precision[query_id]:.4f}")
    print(f"  Recall: {recall[query_id]:.4f}")
    print(f"  F1-score: {f1_scores[query_id]:.4f}")
    print(f"  Documentos relevantes recuperados: {results[query_id]}")
# Out:
# Resultados para la consulta 'trace':
#   Precisión: 1.0000
#   Recall: 0.6250
#   F1-score: 0.7692
#   Documentos relevantes recuperados: [(20792, 0.1796053020267749), (3322, 0.15617376188860607), (3327, 0.15249857033260467), (21371, 0.14002800840280097), (835, 0.1125087900926024), (12337, 0.07474350927519359), (7088, 0.06468462273531508), (19432, 0.05679618342470648)]
#
# Resultados para la consulta 'februari water':
#   Precisión: 1.0000
#   Recall: 0.4009
#   F1-score: 0.5724
#   Documentos relevantes recuperados: [(10295, 0.2357022603955158), (11159, 0.2357022603955158), (7098, 0.2357022603955158), (7554, 0.2357022603955158), (9805, 0.2357022603955158), (10260, 0.22360679774997896), (10384, 0.22360679774997896), (283, 0.22360679774997896), (4698, 0.22360679774997896), (15428, 0.22360679774997896), (5375, 0.22360679774997896), (5378, 0.22360679774997896), (5490, 0.22360679774997896), (7590, 0.22360679774997896), (9748, 0.22360679774997896), (4203, 0.22086305214969307), (10283, 0.21320071635561041), (12403, 0.21320071635561041), (16746, 0.21320071635561041), (11127, 0.21320071635561041), (5768, 0.21320071635561041), (89, 0.2041241452319315), (5498, 0.2041241452319315), (272, 0.2020305089104421), (7007, 0.19611613513818402), (5251, 0.19611613513818402), (13468, 0.19611613513818402), (1716, 0.19611613513818402), (16538, 0.1889822365046136), (5797, 0.1889822365046136), (16549, 0.18257418583505533), (470, 0.18257418583505533), (6860, 0.17149858514250882), (11276, 0.17149858514250882), (406, 0.16666666666666666), (12014, 0.16666666666666666), (16337, 0.16666666666666666), (4454, 0.16222142113076252), (464, 0.16222142113076252), (16813, 0.15811388300841894), (10897, 0.15811388300841894), (17981, 0.15811388300841894), (10099, 0.15811388300841894), (1246, 0.15713484026367722), (10946, 0.1543033499620919), (3445, 0.15249857033260464), (10262, 0.1507556722888818), (12752, 0.1507556722888818), (13188, 0.1507556722888818), (4700, 0.14744195615489714), (6951, 0.14744195615489714), (7555, 0.14744195615489714), (16458, 0.14433756729740646), (4306, 0.14433756729740646), (13471, 0.14433756729740646), (7591, 0.14433756729740646), (15908, 0.14433756729740646), (16100, 0.14433756729740646), (7979, 0.14433756729740646), (16410, 0.1414213562373095), (14785, 0.1414213562373095), (9107, 0.1414213562373095), (9165, 0.1414213562373095), (18225, 0.1414213562373095), (18296, 0.1414213562373095), (12296, 0.1386750490563073), (10332, 0.1386750490563073), (6491, 0.1386750490563073), (8741, 0.1386750490563073), (2872, 0.1386750490563073), (9606, 0.1386750490563073), (5532, 0.1386750490563073), (7585, 0.1386750490563073), (9829, 0.1386750490563073), (14752, 0.13608276348795434), (4787, 0.13608276348795434), (13232, 0.13608276348795434), (11666, 0.13608276348795434), (19975, 0.13608276348795434), (3898, 0.13608276348795434), (6385, 0.13363062095621217), (21173, 0.13363062095621217), (6920, 0.13363062095621217), (8212, 0.13130643285972254), (124, 0.13130643285972254), (12464, 0.13130643285972254), (6354, 0.13130643285972254), (8624, 0.13130643285972254), (10724, 0.13130643285972254), (6982, 0.13130643285972254), (1040, 0.13130643285972254), (5245, 0.13130643285972254), (3207, 0.13130643285972254), (15888, 0.13130643285972254), (3717, 0.13130643285972254), (4238, 0.12909944487358055), (8726, 0.12909944487358055), (21266, 0.12909944487358055), (6975, 0.12909944487358055), (884, 0.12909944487358055), (5146, 0.12909944487358055), (3225, 0.12909944487358055), (1658, 0.12909944487358055), (7836, 0.12909944487358055), (12534, 0.1270001270001905), (14783, 0.1270001270001905), (16854, 0.1270001270001905), (4918, 0.1270001270001905), (7049, 0.1270001270001905), (929, 0.1270001270001905), (17630, 0.1270001270001905), (7634, 0.1270001270001905), (9729, 0.1270001270001905), (4235, 0.12499999999999997), (6297, 0.12499999999999997), (21441, 0.12499999999999997), (11274, 0.12499999999999997), (15430, 0.12499999999999997), (9333, 0.12499999999999997), (3211, 0.12499999999999997), (5260, 0.12499999999999997), (15909, 0.12499999999999997), (10377, 0.12309149097933274), (4255, 0.12309149097933274), (6371, 0.12309149097933274), (10561, 0.12309149097933274), (395, 0.12309149097933274), (442, 0.12309149097933274), (444, 0.12309149097933274), (16843, 0.12309149097933274), (6762, 0.12309149097933274), (21109, 0.12309149097933274), (890, 0.12309149097933274), (5058, 0.12309149097933274), (19447, 0.12309149097933274), (5218, 0.12309149097933274), (5238, 0.123091 ...
